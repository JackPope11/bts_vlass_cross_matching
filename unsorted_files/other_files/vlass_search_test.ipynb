# %% [markdown]
# Testing different ways to get the VLASS cutouts (whether it be fits or arrays). Functions for running batch download and individual downloads.

# %%
import numpy as np
import pandas as pd
import subprocess
import os
import sys
import argparse
import glob
import time
from astropy.io import fits as pyfits
import matplotlib.pyplot as plt
from urllib.request import urlopen
from astropy.table import Table
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from astropy.time import Time
from contextlib import closing
from astropy import units as u

# %%
import warnings
from astropy.wcs import FITSFixedWarning

# Suppress specific FITSFixedWarnings
warnings.filterwarnings('ignore', category=FITSFixedWarning)

# %% [markdown]
# ### Get Tiles Function

# %%
import urllib.request

url = 'https://archive-new.nrao.edu/vlass/VLASS_dyn_summary.php'
output_file = 'VLASS_dyn_summary.php'

urllib.request.urlretrieve(url, output_file)

print(f'File downloaded to: {output_file}')
# Out:
# File downloaded to: VLASS_dyn_summary.php

# %%
def get_tiles():
    """ Get tiles 
    I ran wget https://archive-new.nrao.edu/vlass/VLASS_dyn_summary.php
    """
    fname = "VLASS_dyn_summary.php"
    inputf = open(fname, "r")
    lines = inputf.readlines()
    inputf.close()

    header = list(filter(None, lines[0].split("  ")))
    # get rid of white spaces
    header = np.array([val.strip() for val in header])

    names = []
    dec_min = []
    dec_max = []
    ra_min = []
    ra_max = []
    obsdate = []
    epoch = []

    # Starting at lines[3], read in values
    for line in lines[3:]:
        dat = list(filter(None, line.split("  "))) 
        dat = np.array([val.strip() for val in dat]) 
        names.append(dat[0])
        dec_min.append(float(dat[1]))
        dec_max.append(float(dat[2]))
        ra_min.append(float(dat[3]))
        ra_max.append(float(dat[4]))
        obsdate.append(dat[6])
        epoch.append(dat[5])

    names = np.array(names)
    dec_min = np.array(dec_min)
    dec_max = np.array(dec_max)
    ra_min = np.array(ra_min)
    ra_max = np.array(ra_max)
    obsdate = np.array(obsdate)
    epoch = np.array(epoch)

    return (names, dec_min, dec_max, ra_min, ra_max, epoch, obsdate)


get_tiles()
# Out:
# (array(['T01t01', 'T01t01', 'T01t01', ..., 'T32t02', 'T32t02', 'T32t02'],
#        dtype='<U6'),
#  array([-40., -40., -40., ...,  85.,  85.,  85.]),
#  array([-36., -36., -36., ...,  90.,  90.,  90.]),
#  array([ 0.,  0.,  0., ..., 12., 12., 12.]),
#  array([ 0.5,  0.5,  0.5, ..., 24. , 24. , 24. ]),
#  array(['VLASS1.1', 'VLASS2.1', 'VLASS3.1', ..., 'VLASS3.1', 'VLASS1.1',
#         'VLASS2.1'], dtype='<U8'),
#  array(['2018-02-07', '2020-10-25', '2023-06-06', ..., '2023-04-24',
#         '2017-09-29', '2020-08-29'], dtype='<U13'))

# %% [markdown]
# ### Search Tiles Function

# %%
def search_tiles(tiles, c):
    """ Now that you've processed the file, search for the given RA and Dec
    
    Parameters
    ----------
    c: SkyCoord object
    """
    ra_h = c.ra.hour
    dec_d = c.dec.deg
    names, dec_min, dec_max, ra_min, ra_max, epochs, obsdate = tiles
    has_dec = np.logical_and(dec_d > dec_min, dec_d < dec_max)
    has_ra = np.logical_and(ra_h > ra_min, ra_h < ra_max)
    in_tile = np.logical_and(has_ra, has_dec)
    name = names[in_tile]
    epoch = epochs[in_tile]
    date = obsdate[in_tile]
    if len(name) == 0:
        print("Sorry, no tile found.")
        return None, None, None
    else:
        return name, epoch, date

# %% [markdown]
# ### Get Subtiles Function

# %%
def get_subtiles(tilename, epoch):
    """ For a given tile name, get the filenames in the VLASS directory.
    Parse those filenames and return a list of subtile RA and Dec.
    RA and Dec returned as a SkyCoord object
    """
    if epoch =='VLASS1.2':
        epoch = 'VLASS1.2v2'
    elif epoch =='VLASS1.1':
        epoch = 'VLASS1.1v2'
    url_full = 'https://archive-new.nrao.edu/vlass/quicklook/%s/%s/' %(epoch,tilename)
    urlpath = urlopen(url_full)
    # Get site HTML coding
    string = (urlpath.read().decode('utf-8')).split("\n")
    # clean the HTML elements of trailing and leading whitespace
    vals = np.array([val.strip() for val in string])
    # Make list of HTML link elements
    keep_link = np.array(["href" in val.strip() for val in string])
    # Make list of HTML elements with the tile name
    keep_name = np.array([tilename in val.strip() for val in string])
    # Cross reference the two lists above to keep only the HTML elements with the tile name and a link
    string_keep = vals[np.logical_and(keep_link, keep_name)]
    # Keep only the links from the HTML elements (they are the 7th element since 6 quote marks precede it)
    fname = np.array([val.split("\"")[7] for val in string_keep])
    # Take out the element of the link that encodes the RA and declination
    pos_raw = np.array([val.split(".")[4] for val in fname])
    if '-' in pos_raw[0]:
        # dec < 0
        ra_raw = np.array([val.split("-")[0] for val in pos_raw])
        dec_raw = np.array([val.split("-")[1] for val in pos_raw])
    else:
        # dec > 0
        ra_raw = np.array([val.split("+")[0] for val in pos_raw])
        dec_raw = np.array([val.split("+")[1] for val in pos_raw])
    ra = []
    dec = []
    for ii,val in enumerate(ra_raw):
        # 24 hours is the same as hour 0
        if val[1:3] == '24':
            rah = '00'
        else:
            rah = val[1:3]
        # calculate RA in hours mins and seconds
        hms = "%sh%sm%ss" %(rah, val[3:5], val[5:])
        ra.append(hms)
        # calculate Dec in degrees arcminutes and arcseconds
        dms = "%sd%sm%ss" %(
                dec_raw[ii][0:2], dec_raw[ii][2:4], dec_raw[ii][4:])
        dec.append(dms)
    ra = np.array(ra)
    dec = np.array(dec)
    c_tiles = SkyCoord(ra, dec, frame='icrs')
    return fname, c_tiles

# %% [markdown]
# ### Get Numpy Cutout Function

# %%
def get_cutout(imname, name, c, epoch, save_dir, download_image = True):

    # Position of source
    ra_deg = c.ra.deg
    dec_deg = c.dec.deg

    print("Cutout centered at position %s, %s" % (ra_deg, dec_deg))

    try:
        # Open image and establish coordinate system
        with pyfits.open(imname) as hdul:
            im = hdul[0].data[0, 0]
            w = WCS(hdul[0].header)
        
            # Find the source position in pixels.
            # This will be the center of our image.
            src_pix = w.wcs_world2pix([[ra_deg, dec_deg, 0, 0]], 0)
            x = src_pix[0, 0] + 1
            y = src_pix[0, 1] + 1

            # Check if the source is actually in the image
            pix1 = hdul[0].header['CRPIX1']
            pix2 = hdul[0].header['CRPIX2']
            badx = np.logical_or(x < 0, x > 2 * pix1)
            bady = np.logical_or(y < 0, y > 2 * pix2)
            if np.logical_and(badx, bady):
                print("Tile has not been imaged at the position of the source")
                return None
            else:
                # Set the dimensions of the image
                # Say we want it to be 12 arcseconds on a side,
                # to match the DES images
                image_dim_arcsec = 12
                delt1 = hdul[0].header['CDELT1']
                delt2 = hdul[0].header['CDELT2']
                cutout_size = image_dim_arcsec / 3600  # in degrees
                dside1 = -cutout_size / 2. / delt1
                dside2 = cutout_size / 2. / delt2

                vmin = -1e-4
                vmax = 1e-3

                im_plot_raw = im[int(y - dside1):int(y + dside1), int(x - dside2):int(x + dside2)]
                im_plot = np.ma.masked_invalid(im_plot_raw)

                # 3-sigma clipping (find root mean square of values that are not above 3 standard deviations)
                rms_temp = np.ma.std(im_plot)
                keep = np.ma.abs(im_plot) <= 3 * rms_temp
                rms = np.ma.std(im_plot[keep])

                # Find peak flux in entire image
                # Check if im_plot.flatten() is empty
                if im_plot.flatten().size == 0:
                    print("Tile has not been imaged at the position of the source")
                    return None
                else:
                    peak_flux = np.ma.max(im_plot.flatten())

                fig, ax = plt.subplots(figsize=(6, 6))  # Create a square figure
                ax.imshow(
                    np.flipud(im_plot),
                    extent=[-0.5 * cutout_size * 3600., 0.5 * cutout_size * 3600.,
                            -0.5 * cutout_size * 3600., 0.5 * cutout_size * 3600],
                    vmin=vmin, vmax=vmax, cmap='YlOrRd')

                peakstr = "Peak Flux %s mJy" % (np.round(peak_flux * 1e3, 3))
                rmsstr = "RMS Flux %s mJy" % (np.round(rms * 1e3, 3))

                title_str = r'$\bf{%s}$' % epoch + '\n' + '%s: %s;\n%s' % (name, peakstr, rmsstr)
                ax.set_title(title_str, fontsize=10)
                ax.set_xlabel("Offset in RA (arcsec)")
                ax.set_ylabel("Offset in Dec (arcsec)")

                ax.set_aspect('equal')  # Ensure the plot is square
                ax.figure.tight_layout()  # Adjust layout to fit everything nicely

                filename = f"{name}_{epoch}.png"
                filepath = os.path.join(save_dir, filename)
                plt.savefig(filepath)
                plt.close(fig)

                print(f"PNG saved successfully: {filepath}")

        return peak_flux, rms, filepath

    except Exception as e:
        print(f"An error occurred while processing {imname}: {e}")
        return None

# %% [markdown]
# ### Run Search Function

# %%
# # Example coordinates
# coord_str = "13:14:25.45 +50:58:39.7"
# c1 = SkyCoord(coord_str, unit=(u.hourangle, u.deg))

# name = "ZTF18aagrtxs"




# coord_str2 = "10:35:32.09 +37:38:59.0"
# name = "ZTF17aabtvsy"
# c2 = SkyCoord(coord_str2, unit=(u.hourangle, u.deg))


# file_path = 'ia_supernovae_stuff/ia_full_data/ia_supernovae.csv'
# ia_supernovae_df = pd.read_csv(file_path)
# test_df = ia_supernovae_df.iloc[20:23]

# test_df

# %% [markdown]
# ### Multiple objects to Event List
# and helper functions

# %%
# dataframe = pd.read_csv('ztf_transients.csv')

# %%
def dataframe_to_objects(dataframe, name_id_col = 'ZTFID', ra_id_col = 'RA', dec_id_col = 'Dec'):

    new_dataframe = []
    for i, object in dataframe.iterrows():
        name = object[name_id_col]
        coord_str = object[ra_id_col] + object[dec_id_col]
        c = SkyCoord(coord_str, unit=(u.hourangle, u.deg))
        object_data = {'Name': name,
                       'Skycoord': c}
        new_dataframe.append(object_data)
    return new_dataframe

# dataframe_to_objects(test_df)

# %%
def search_tiles_and_sort(c):
    """
    Gets tiles and sorts the available epochs in order, returning tiles, epochs, and their observed dates
    """

    tiles = get_tiles()
    tilenames, epochs, obsdates = search_tiles(tiles, c)

    # Sort the tiles by the epochs so most recent goes last
    combined = list(zip(tilenames, epochs, obsdates))
    combined_sorted = sorted(combined, key=lambda x: x[1])
    tilenames, epochs, obsdates = zip(*combined_sorted)

    return tilenames, epochs, obsdates

# %%
def boolean_observed_tiles(tilenames):
    """
    Checks if there is a list of tilenames (from search_tiles_and_sort) or if it is just None

    Returns True if there are tiles
    Returns False if there are none
    """
    if tilenames[0] is None:
        return False
    else:
        return True

# %%
def object_to_multiple_epochs(name, c):
    """
    Takes the list of lists from search_tiles_and_sort and makes them into separate dictionaries,
    each representing a unique epoch-date observed
    """

    object_lists = []
    set_list = search_tiles_and_sort(c)
    # get the length of the individual lists (how many epochs show up)
    for x in range(len(set_list[0])):
        obs = {'Name': name,
               'c': c,
               'Tile': set_list[0][x],
               'Epoch': set_list[1][x],
               'Date': set_list[2][x]}
        object_lists.append(obs)

    return object_lists

# %%
def multiple_objects_to_event_list(dataframe, name_id_col = 'ZTFID', ra_id_col = 'RA', dec_id_col = 'Dec'):
    
    """ Given a pandas dataframe with name, ra, and dec, returns the a list of dictionaries
    which each have the name, skycoord, tile, epoch, and date of observation
    """

    final_object_epoch_list = []
    list_dict = dataframe_to_objects(dataframe, name_id_col, ra_id_col, dec_id_col)
    for obj in list_dict:
        name = obj['Name']
        c = obj['Skycoord']
        list_epoch_tiles = object_to_multiple_epochs(name, c)
        print(name)
        for x in list_epoch_tiles:
            final_object_epoch_list.append(x)

    return final_object_epoch_list

# %%
# multiple_objects_to_event_list(dataframe)

# %%
def pull_observed_tiles(most_recent_epoch = "VLASS3.2"):
    """
    Get all tiles that have been observed and put them into a list
    """

    url_full = 'https://archive-new.nrao.edu/vlass/quicklook/%s/' %(most_recent_epoch)
    with closing(urlopen(url_full)) as urlpath:
        # Get site HTML coding
        string = (urlpath.read().decode('utf-8')).split("\n")
        # clean the HTML elements of trailing and leading whitespace
        vals = np.array([val.strip() for val in string])
        # Make list of useful html elements
        files = np.array(['alt="[DIR]"' in val.strip() for val in string])
        useful = vals[files]
        # Splice out the name from the link
        obsname = np.array([val.split("\"")[7] for val in useful])
        observed_tiles_current_epoch = np.char.replace(obsname, '/', '')
        
    return observed_tiles_current_epoch

# %%
def check_obsdate(obsdate):
    """
    Checks an observed date and converts it to the proper date format (iso)
        if it is not "Not Submitted" or "Scheduled
    
    """
    # first check that the date isn't a special description
    if obsdate not in ['Scheduled', 'Not submitted']:
        try:
            obsdate = Time(obsdate, format='iso')
        except ValueError as e:
            print(f"Invalid date format: {obsdate}. Error: {e}")
            obsdate = 'Invalid date'
    # if it is, just say it's an invalid date
    else:
        obsdate = f"Invalid Date: '{obsdate}'"

    return obsdate

# %%
def adjust_epoch(epoch):
    """
    Changes the name of the epoch from VLASS1.1 and VLASS1.2 to VLASS1.1v2 and 1.2v2 respectively
    """
    # adjust epoch names to properly match
    if epoch=='VLASS1.2':
        epoch = 'VLASS1.2v2'
    elif epoch =='VLASS1.1':
        epoch = 'VLASS1.1v2'

    return epoch

# %%
def check_epoch_observed(epoch, tilename, observed_tiles_current_epoch):
    """
    Checks if the tile is observed based on what epoch we're in
    """
    # define past and present epochs
    past_epochs = ["VLASS1.1v2", "VLASS1.2v2", "VLASS2.1", "VLASS2.2", "VLASS3.1"]
    current_epoch = "VLASS3.2"

    # if it's a past epoch, we know it was observed
    if epoch in past_epochs:
        observed = True
    else:
        # if it's in current epoch, we need to check if it's been observed yet
        if epoch == current_epoch:
            # check if tile has been observed
            if tilename in observed_tiles_current_epoch:
                observed = True
        # if different epoch or hasn't been observed, set observed to False
        else:
            observed = False

    return observed

# %%
def get_and_check_subtile(c, epoch, tilename):
    """
    If the tile was assumed to be observed, get the nearest subtile to the coordinates of the object
    """
    subtiles, c_tiles = get_subtiles(tilename, epoch)
    # check that there are actually some subtiles
    if c_tiles == []:
        subtile = None
    else:
        # Find angular separation from the tiles to the location
        dist = c.separation(c_tiles)
        # Find tile with the smallest separation 
        subtile = subtiles[np.argmin(dist)]

    return subtile

# %%
def image_and_url_getter(subtile, epoch, tilename):
    """
    Given a subtile, return the NRAO url
    """
    fits_url = "https://archive-new.nrao.edu/vlass/quicklook/%s/%s/%s" %(
            epoch, tilename, subtile)
    fitsname = "%s.I.iter1.image.pbcor.tt0.subim.fits" %subtile[0:-1]

    return fits_url, fitsname

# %%
import os
import subprocess

def get_fits(fits_url, fitsname, fits_dir="ia_fits"):
    """
    Given the fits_url and fitsname, checks if the FITS file is downloaded in fits_dir
    and downloads it if it hasn't been already.
    """
    # Ensure the directory exists
    if not os.path.exists(fits_dir):
        os.makedirs(fits_dir)

    # Define the local path for the FITS file
    local_fits_path = os.path.join(fits_dir, fitsname)

    # Check if FITS file has already been downloaded
    if os.path.exists(local_fits_path):
        print(f"{local_fits_path} already exists. Skipping download.")
        return local_fits_path

    # Define the full URL for the FITS file
    full_fits_url = fits_url + fitsname

    # Attempt to download the FITS file
    try:
        print(f"Downloading {fitsname}...")
        subprocess.run(
            ["curl", "-o", local_fits_path, full_fits_url],
            check=True
        )

        # Confirm if the file was downloaded successfully
        if os.path.exists(local_fits_path):
            print(f"Downloaded {fitsname} successfully.")
            return local_fits_path
        else:
            print(f"Failed to download {fitsname}. File not found after download attempt.")
            return None

    except subprocess.CalledProcessError:
        # Handle any errors from the curl command
        print(f"Error downloading {fitsname}. Check the URL or network connection.")
        return None

# %%
def get_numpy_array(local_fits_path, c):
    """
    Given a fits path, gets the array centered around the skycoords c
    """

    # Position of source
    ra_deg = c.ra.deg
    dec_deg = c.dec.deg

    try:
        # Open image and establish coordinate system
        with pyfits.open(local_fits_path) as hdul:
            im = hdul[0].data[0, 0]
            w = WCS(hdul[0].header)
        
            # Find the source position in pixels.
            # This will be the center of our image.
            src_pix = w.wcs_world2pix([[ra_deg, dec_deg, 0, 0]], 0)
            x = src_pix[0, 0] + 1
            y = src_pix[0, 1] + 1

            # Check if the source is actually in the image
            pix1 = hdul[0].header['CRPIX1']
            pix2 = hdul[0].header['CRPIX2']
            badx = np.logical_or(x < 0, x > 2 * pix1)
            bady = np.logical_or(y < 0, y > 2 * pix2)
            if np.logical_and(badx, bady):
                print("Tile has not been imaged at the position of the source")
                return None
            else:
                # Set the dimensions of the image
                # Say we want it to be 12 arcseconds on a side,
                # to match the DES images
                image_dim_arcsec = 12
                delt1 = hdul[0].header['CDELT1']
                delt2 = hdul[0].header['CDELT2']
                cutout_size = image_dim_arcsec / 3600  # in degrees
                dside1 = -cutout_size / 2. / delt1
                dside2 = cutout_size / 2. / delt2

                im_plot_raw = im[int(y - dside1):int(y + dside1), int(x - dside2):int(x + dside2)]
                im_plot = np.ma.masked_invalid(im_plot_raw)

                return im_plot
            
    except Exception as e:
        print(f"An error occurred while processing {local_fits_path}: {e}")
        return None

# %%
def check_image(local_fits_path, name, c, epoch):

    # Position of source
    ra_deg = c.ra.deg
    dec_deg = c.dec.deg

    print("Cutout centered at position %s, %s" % (ra_deg, dec_deg))

    try:
        # Open image and establish coordinate system
        with pyfits.open(local_fits_path) as hdul:
            im = hdul[0].data[0, 0]
            w = WCS(hdul[0].header)
        
            # Find the source position in pixels.
            # This will be the center of our image.
            src_pix = w.wcs_world2pix([[ra_deg, dec_deg, 0, 0]], 0)
            x = src_pix[0, 0] + 1
            y = src_pix[0, 1] + 1

            # Check if the source is actually in the image
            pix1 = hdul[0].header['CRPIX1']
            pix2 = hdul[0].header['CRPIX2']
            badx = np.logical_or(x < 0, x > 2 * pix1)
            bady = np.logical_or(y < 0, y > 2 * pix2)
            if np.logical_and(badx, bady):
                print("Tile has not been imaged at the position of the source")
                return None
            else:
                # Set the dimensions of the image
                # Say we want it to be 12 arcseconds on a side,
                # to match the DES images
                image_dim_arcsec = 12
                delt1 = hdul[0].header['CDELT1']
                delt2 = hdul[0].header['CDELT2']
                cutout_size = image_dim_arcsec / 3600  # in degrees
                dside1 = -cutout_size / 2. / delt1
                dside2 = cutout_size / 2. / delt2

                vmin = -1e-4
                vmax = 1e-3

                im_plot_raw = im[int(y - dside1):int(y + dside1), int(x - dside2):int(x + dside2)]
                im_plot = np.ma.masked_invalid(im_plot_raw)

                # 3-sigma clipping (find root mean square of values that are not above 3 standard deviations)
                rms_temp = np.ma.std(im_plot)
                keep = np.ma.abs(im_plot) <= 3 * rms_temp
                rms = np.ma.std(im_plot[keep])

                # Find peak flux in entire image
                # Check if im_plot.flatten() is empty
                if im_plot.flatten().size == 0:
                    print("Tile has not been imaged at the position of the source")
                    return None
                else:
                    peak_flux = np.ma.max(im_plot.flatten())

                fig, ax = plt.subplots(figsize=(6, 6))  # Create a square figure
                ax.imshow(
                    np.flipud(im_plot),
                    extent=[-0.5 * cutout_size * 3600., 0.5 * cutout_size * 3600.,
                            -0.5 * cutout_size * 3600., 0.5 * cutout_size * 3600],
                    vmin=vmin, vmax=vmax, cmap='YlOrRd')

                peakstr = "Peak Flux %s mJy" % (np.round(peak_flux * 1e3, 3))
                rmsstr = "RMS Flux %s mJy" % (np.round(rms * 1e3, 3))

                title_str = r'$\bf{%s}$' % epoch + '\n' + '%s: %s;\n%s' % (name, peakstr, rmsstr)
                ax.set_title(title_str, fontsize=10)
                ax.set_xlabel("Offset in RA (arcsec)")
                ax.set_ylabel("Offset in Dec (arcsec)")

                ax.set_aspect('equal')  # Ensure the plot is square
                ax.figure.tight_layout()  # Adjust layout to fit everything nicely


    except Exception as e:
        print(f"An error occurred while processing {local_fits_path}: {e}")
        return None

# %%
import os
import numpy as np

def save_npy_array(name, epoch, array, save_dir = 'ia_npy_arrays'):

    # Convert masked array to a regular ndarray (removes the mask)
    array = array.filled(np.nan)  # Replace masked values with NaN (or any value you prefer)

    # Make sure folder exists
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Define name of the file
    file_path = os.path.join(save_dir, f"{name}_{epoch}_array.npy")

    # Check if the file already exists
    if os.path.exists(file_path):
        print(f"File {file_path} already exists. Skipping save.")
        return file_path # Exit the function if the file exists

    # Save the array as a .npy to the folder
    np.save(file_path, array)
    
    print(f"Array saved to {file_path}")
    return file_path

# %%
def event_to_npy(name, c, tile, epoch):
    """ 
    Converts a single event, given name, skycoord, the tile, epoch, and date
    (individual objects from multiple_objects_to_events)
    and saves the fits and the array, returning the file path for the array
    """
    
    # check if tile was observed
    curr_obs_tiles = pull_observed_tiles()
    epoch = adjust_epoch(epoch)
    observed = check_epoch_observed(epoch, tile, curr_obs_tiles)

    # if observed, check subtiles
    if observed:
        subtile = get_and_check_subtile(c, epoch, tile)
        # if subtile exists, save the array
        if subtile is not None:
            fits_url, fitsname = image_and_url_getter(subtile, epoch, tile)
            local_fits_path = get_fits(fits_url, fitsname, fits_dir="ia_fits")
            array = get_numpy_array(local_fits_path, c)
            file_path = save_npy_array(name, epoch, array, save_dir = 'ia_npy_arrays')
            return file_path
        # if subtile doesn't exist, return NA
        else:
            print('Subtile does not exist')
            return 'NA'
    else:
        print('Object not observed')
        return 'NA'

# %%
def objects_to_df(in_dataframe, out_dataframe):
    """
    Takes a dataframe from multiple_objects_to_event_list and converts it to a
    pandas DataFrame, saving file paths and other information.

    out_dataframe must be a DataFrame with columns 'Name', 'Ra_hourangle', 
    'Dec_degree', 'Epoch', 'Date', 'File_path'.
    """
    
    start_total = time.time()
    rows = []  # Collect rows here for efficiency
    
    for event in in_dataframe:
        start_event = time.time()

        # Extract fields
        name = event['Name']
        c = event['c']
        ra_hourangle = c.ra.hourangle
        dec_degree = c.dec.degree
        tile = event['Tile']
        epoch = event['Epoch']
        date = event['Date']
        
        # Generate file path
        start_file_path = time.time()
        file_path = event_to_npy(name, c, tile, epoch)
        print(f"Time for file path generation: {time.time() - start_file_path:.4f} seconds")

        # Add the row to the list
        rows.append({
            'Name': name,
            'Ra_hourangle': ra_hourangle,
            'Dec_degree': dec_degree,
            'Epoch': epoch,
            'Date': date,
            'File_path': file_path
        })
        
        # Total time for this event
        print(f"Time for processing event: {time.time() - start_event:.4f} seconds\n")

    # Convert rows to a DataFrame
    new_rows_df = pd.DataFrame(rows)

    # Check if out_dataframe is empty
    if out_dataframe.empty:
        out_dataframe = new_rows_df
    else:
        out_dataframe = pd.concat([out_dataframe, new_rows_df], ignore_index=True)

    out_dataframe.to_csv("ia_supernovae_with_file_path.csv", index=False)
    print("Dataframe written to: ia_supernovae_with_file_path.csv")

    # Total time for all events
    print(f"Total time for all events: {time.time() - start_total:.4f} seconds")
    return out_dataframe

# %%
import os
import pandas as pd

def update_csv(start_row, end_row, csv_name="ia_supernovae_with_file_path.csv",
                file_path = "ia_supernovae_stuff/ia_full_data/ia_supernovae.csv"):
    """
    Updates or initializes a CSV file with processed data from a subset of a DataFrame.

    Parameters:
    - start_row: Starting row index for the subset
    - end_row: Ending row index for the subset
    - csv_name: Name of the output CSV file to update or create
    - file_name: Name of the file that contains the list of the transients being looked at
    """
    
    # Load the original DataFrame
    ia_supernovae_df = pd.read_csv(file_path)
    test_df = ia_supernovae_df.iloc[start_row:end_row]
    
    # Check if the output CSV exists
    if os.path.exists(csv_name):
        # If it exists, load the existing DataFrame
        out_df = pd.read_csv(csv_name)
    else:
        # Initialize the DataFrame if the file doesn't exist
        out_df = pd.DataFrame(columns=['Name', 'Ra_hourangle', 'Dec_degree', 'Epoch', 'Date', 'File_path'])

    # Process and append rows
    out_df = objects_to_df(multiple_objects_to_event_list(test_df), out_df)
    
    # Save back to the CSV
    out_df.to_csv(csv_name, index=False)
    print(f"CSV updated: {csv_name}")

# %% [markdown]
# ### Batch Functions

# %%
def assign_indices(data):
    """
    Assigns indices to a list of dictionaries based on the 'Name' key,
    with padding to two digits (e.g., 01, 02).

    Args:
        data (list): A list of dictionaries, each containing a 'Name' key.

    Returns:
        list: The input list of dictionaries with an added 'Index' key for each dictionary.
    """
    # Step 1: Create a mapping of names to indices
    name_to_index = {}
    current_index = 1

    for entry in data:
        name = entry['Name']
        if name not in name_to_index:
            # Assign a new index if the name hasn't been seen
            name_to_index[name] = f"{current_index:02}"
            current_index += 1

    # Step 2: Add the index to each entry in the data
    for entry in data:
        entry['Index'] = name_to_index[entry['Name']]

    return data

# %%
def assign_indices(data):
    """
    Assigns indices to a list of dictionaries based on the 'Name' key,
    with padding dynamically adjusted to the number of unique names.

    Args:
        data (list): A list of dictionaries, each containing a 'Name' key.

    Returns:
        list: The input list of dictionaries with an added 'Index' key for each dictionary.
    """
    # Step 1: Get the unique names and calculate the required padding
    unique_names = sorted({entry['Name'] for entry in data})
    padding = len(str(len(unique_names)))  # Determine the number of digits for padding

    # Step 2: Create a mapping of names to indices with proper padding
    name_to_index = {name: f"{i+1:0{padding}}" for i, name in enumerate(unique_names)}

    # Step 3: Add the index to each entry in the data
    for entry in data:
        entry['Index'] = name_to_index[entry['Name']]

    return data

# %%
import re

def extract_epoch_number(data):
    """
    Extracts the numeric part of the 'Epoch' field in each dictionary and adds it as a new key 'Epoch_Number'.

    Args:
        data (list): A list of dictionaries with an 'Epoch' field.

    Returns:
        list: The input list with an added 'Epoch_Number' key for each dictionary.
    """
    for entry in data:
        # Use regex to extract the numeric part of the epoch (e.g., "1.1" from "VLASS1.1")
        match = re.search(r'(\d+\.\d+)', entry['Epoch'])
        if match:
            entry['Epoch_Number'] = match.group(1)
        else:
            entry['Epoch_Number'] = None  # In case no match is found, handle gracefully
    return data

# %%
def match_files_to_data(data, batch_fits_folder):
    """
    Matches each dictionary in the data list with a corresponding file in the batch_fits folder.

    Args:
        data (list): List of dictionaries, each containing 'Epoch_Number' and 'Index'.
        batch_fits_folder (str): Path to the folder containing the FITS files.

    Returns:
        list: The input data list with an added 'Matched_File' key for each dictionary.
    """
    # Get all files in the batch_fits folder
    all_files = os.listdir(batch_fits_folder)
    
    for entry in data:
        epoch_number = entry.get('Epoch_Number')
        index = entry.get('Index')
        matched_file = None
        
        # Match files with both Index and Epoch_Number
        for file_name in all_files:
            if file_name.startswith(f"{index}-") and epoch_number in file_name:
                matched_file = os.path.join(batch_fits_folder, file_name)
                break  # Stop searching once a match is found

        # Add the matched file path (or None if no match found) to the entry
        entry['Matched_File'] = matched_file
    
    return data

# %%
def centered_get_numpy_array(local_fits_path, c):
    """
    Given a fits path, gets the array centered around the skycoords c
    """

    # Position of source
    ra_deg = c.ra.deg
    dec_deg = c.dec.deg

    try:
        # Open image and establish coordinate system
        with pyfits.open(local_fits_path) as hdul:
            im = hdul[0].data[0, 0]
            w = WCS(hdul[0].header)
        
            # Find the source position in pixels.
            # This will be the center of our image.
            src_pix = w.wcs_world2pix([[ra_deg, dec_deg, 0, 0]], 0)
            x = src_pix[0, 0] + 1
            y = src_pix[0, 1] + 1

            # Check if the source is actually in the image
            pix1 = hdul[0].header['CRPIX1']
            pix2 = hdul[0].header['CRPIX2']
            # Set the dimensions of the image
            # Say we want it to be 12 arcseconds on a side,
            # to match the DES images
            image_dim_arcsec = 12
            delt1 = hdul[0].header['CDELT1']
            delt2 = hdul[0].header['CDELT2']
            cutout_size = image_dim_arcsec / 3600  # in degrees
            dside1 = -cutout_size / 2. / delt1
            dside2 = cutout_size / 2. / delt2

            im_plot_raw = im[int(y - dside1):int(y + dside1), int(x - dside2):int(x + dside2)]
            im_plot = np.ma.masked_invalid(im_plot_raw)

            return im_plot
        
    except Exception as e:
        print(f"An error occurred while processing {local_fits_path}: {e}")
        return None

# %%
def centered_check_image(local_fits_path, name, c, epoch):

    # Position of source
    ra_deg = c.ra.deg
    dec_deg = c.dec.deg

    print("Cutout centered at position %s, %s" % (ra_deg, dec_deg))

    try:
        # Open image and establish coordinate system
        with pyfits.open(local_fits_path) as hdul:
            im = hdul[0].data[0, 0]
            w = WCS(hdul[0].header)
        
            # Find the source position in pixels.
            # This will be the center of our image.
            src_pix = w.wcs_world2pix([[ra_deg, dec_deg, 0, 0]], 0)
            x = src_pix[0, 0] + 1
            y = src_pix[0, 1] + 1

            # Check if the source is actually in the image
            pix1 = hdul[0].header['CRPIX1']
            pix2 = hdul[0].header['CRPIX2']

            # Set the dimensions of the image
            # Say we want it to be 12 arcseconds on a side,
            # to match the DES images
            image_dim_arcsec = 12
            delt1 = hdul[0].header['CDELT1']
            delt2 = hdul[0].header['CDELT2']
            cutout_size = image_dim_arcsec / 3600  # in degrees
            dside1 = -cutout_size / 2. / delt1
            dside2 = cutout_size / 2. / delt2

            vmin = -1e-4
            vmax = 1e-3

            im_plot_raw = im[int(y - dside1):int(y + dside1), int(x - dside2):int(x + dside2)]
            im_plot = np.ma.masked_invalid(im_plot_raw)

            # 3-sigma clipping (find root mean square of values that are not above 3 standard deviations)
            rms_temp = np.ma.std(im_plot)
            keep = np.ma.abs(im_plot) <= 3 * rms_temp
            rms = np.ma.std(im_plot[keep])

            # Find peak flux in entire image
            # Check if im_plot.flatten() is empty
            if im_plot.flatten().size == 0:
                print("Tile has not been imaged at the position of the source")
                return None
            else:
                peak_flux = np.ma.max(im_plot.flatten())

            fig, ax = plt.subplots(figsize=(6, 6))  # Create a square figure
            ax.imshow(
                np.flipud(im_plot),
                extent=[-0.5 * cutout_size * 3600., 0.5 * cutout_size * 3600.,
                        -0.5 * cutout_size * 3600., 0.5 * cutout_size * 3600],
                vmin=vmin, vmax=vmax, cmap='YlOrRd')

            peakstr = "Peak Flux %s mJy" % (np.round(peak_flux * 1e3, 3))
            rmsstr = "RMS Flux %s mJy" % (np.round(rms * 1e3, 3))

            title_str = r'$\bf{%s}$' % epoch + '\n' + '%s: %s;\n%s' % (name, peakstr, rmsstr)
            ax.set_title(title_str, fontsize=10)
            ax.set_xlabel("Offset in RA (arcsec)")
            ax.set_ylabel("Offset in Dec (arcsec)")

            ax.set_aspect('equal')  # Ensure the plot is square
            ax.figure.tight_layout()  # Adjust layout to fit everything nicely


    except Exception as e:
        print(f"An error occurred while processing {local_fits_path}: {e}")
        return None

# %%
coord_str = "12:35:52.28 +27:55:55.4"
c1 = SkyCoord(coord_str, unit=(u.hourangle, u.deg))


c1 = SkyCoord(coord_str, unit=(u.hourangle, u.deg))


centered_check_image('D:\summer_research_code\Query_VLASS_2\ztf_cutouts\ztf_cutouts_no_interp\._ZTF17aaapufz_epoch_1.fits',
                     'hola', c1, '1')


name = "ZTFaaapufz"
# Out:
# Cutout centered at position 188.96783333333332, 27.932055555555557
# An error occurred while processing D:\summer_research_code\Query_VLASS_2\ztf_cutouts\ztf_cutouts_no_interp\._ZTF17aaapufz_epoch_1.fits: No SIMPLE card found, this file does not appear to be a valid FITS file. If this is really a FITS file, try with ignore_missing_simple=True

# %%
def batch_event_to_npy(name, c, tile, epoch, local_fits_path):
    """ 
    Converts a single event, given name, skycoord, the tile, epoch, and date
    (individual objects from multiple_objects_to_events)
    and saves the fits and the array, returning the file path for the array
    """

    epoch = adjust_epoch(epoch)

    if local_fits_path != None:
        array = centered_get_numpy_array(local_fits_path, c)
        file_path = save_npy_array(name, epoch, array, save_dir = 'ia_npy_arrays')
        return file_path
    else:
        return('NA')

# %%
def batch_objects_to_df(in_dataframe, out_dataframe):
    """
    Takes a dataframe from matched_files_to_data and converts it to a
    pandas DataFrame, saving file paths and other information.

    out_dataframe must be a DataFrame with columns 'Name', 'Ra_hourangle', 
    'Dec_degree', 'Epoch', 'Date', 'File_path'.
    """
    
    start_total = time.time()
    rows = []  # Collect rows here for efficiency
    
    for event in in_dataframe:
        start_event = time.time()

        # Extract fields
        name = event['Name']
        c = event['c']
        ra_hourangle = c.ra.hourangle
        dec_degree = c.dec.degree
        tile = event['Tile']
        epoch = event['Epoch']
        date = event['Date']
        local_fits_path = event['Matched_File']
        

        # Generate file path
        start_file_path = time.time()
        file_path = batch_event_to_npy(name, c, tile, epoch, local_fits_path)
        print(f"Time for file path generation: {time.time() - start_file_path:.4f} seconds")

        # Add the row to the list
        rows.append({
            'Name': name,
            'Ra_hourangle': ra_hourangle,
            'Dec_degree': dec_degree,
            'Epoch': epoch,
            'Date': date,
            'File_path': file_path
        })
        
        # Total time for this event
        print(f"Time for processing event: {time.time() - start_event:.4f} seconds\n")

    # Convert rows to a DataFrame
    new_rows_df = pd.DataFrame(rows)

    # Check if out_dataframe is empty
    if out_dataframe.empty:
        out_dataframe = new_rows_df
    else:
        out_dataframe = pd.concat([out_dataframe, new_rows_df], ignore_index=True)

    out_dataframe.to_csv("ia_supernovae_with_file_path.csv", index=False)
    print("Dataframe written to: ia_supernovae_with_file_path.csv")

    # Total time for all events
    print(f"Total time for all events: {time.time() - start_total:.4f} seconds")
    return out_dataframe

# %%
def batch_update_csv(start_row, end_row, 
                     csv_name = "ia_supernovae_with_file_path.csv",
                     file_path = "ia_supernovae_stuff/ia_full_data/ia_supernovae.csv"):
    """
    Updates or initializes a CSV file with processed data from a subset of a DataFrame.

    Parameters:
        - csv_name: Name of the output CSV file to update or create
        - file_name: Name of the file that contains the list of the transients being looked at
    """

    # Load the original DataFrame
    ia_supernovae_df = pd.read_csv(file_path)
    test_df = ia_supernovae_df.iloc[start_row:end_row]

    # Check if the output CSV exists
    if os.path.exists(csv_name):
        # If it exists, load the existing DataFrame
        out_df = pd.read_csv(csv_name)
    else:
        # Initialize the DataFrame if the file doesn't exist
        out_df = pd.DataFrame(columns=['Name', 'Ra_hourangle', 'Dec_degree', 'Epoch', 'Date', 'File_path'])
    

    # takes the event list and adds the index and epoch number to allow to search for batch_fits file
    primed_event_list = extract_epoch_number(assign_indices(multiple_objects_to_event_list(test_df)))

    # take the event list and add the batch_fits file names to them
    primed_event_list = match_files_to_data(primed_event_list, "batch_fits")

    return batch_objects_to_df(primed_event_list, out_df)

# %%
def clean_batch_fits():

    # Path to the folder you want to clear
    folder_path = 'batch_fits'

    # Loop through the contents of the folder and remove them
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        try:
            if os.path.isdir(file_path):
                shutil.rmtree(file_path)  # Remove subdirectories and their contents
            else:
                os.remove(file_path)  # Remove files
        except Exception as e:
            print(f"Error removing {file_path}: {e}")



clean_batch_fits()

# %%
def renew_batch_file(start, end, supernovae_list_csv = 'ia_supernovae_stuff/ia_full_data/ia_supernovae.csv'):
    df = pd.read_csv(supernovae_list_csv)
    df_subset = df.iloc[start:end]
    df_subset.to_csv('batch.csv', index=False)

renew_batch_file(2930, 3030)

# %%
import os
import tarfile
from pathlib import Path

def extract_and_cleanup_tgz(downloads_path, extract_to, tgz_filename):
    # Full path to the .tgz file
    tgz_file_path = os.path.join(downloads_path, tgz_filename)
    
    # Check if the file exists
    if not os.path.exists(tgz_file_path):
        print(f"File not found: {tgz_file_path}")
        return
    
    print(f"Found file: {tgz_file_path}")
    
    # Extract the .tgz file
    try:
        with tarfile.open(tgz_file_path, 'r:gz') as tar_ref:
            tar_ref.extractall(extract_to)
            print(f"Extracted to: {extract_to}")
    except Exception as e:
        print(f"Error during extraction: {e}")
        return
    
    # Attempt to remove the .tgz file
    try:
        os.remove(tgz_file_path)
        print(f"Removed file: {tgz_file_path}")
    except Exception as e:
        print(f"Error removing file: {tgz_file_path} - {e}")

# Set your downloads path and target extraction folder
downloads_folder = str(Path.home() / "Downloads")
target_folder = "D:/summer_research_code/Query_VLASS_2/batch_fits"
tgz_filename = "batch_cutoutResults.tgz"

# Ensure the target folder exists
os.makedirs(target_folder, exist_ok=True)
    
# Run the function
extract_and_cleanup_tgz(downloads_folder, target_folder, tgz_filename)
# Out:
# Found file: C:\Users\Jack Pope\Downloads\batch_cutoutResults.tgz
# Extracted to: D:/summer_research_code/Query_VLASS_2/batch_fits
# Removed file: C:\Users\Jack Pope\Downloads\batch_cutoutResults.tgz

# %%
batch_update_csv(2930, 3030)
# Out:
# File ia_npy_arrays\ZTF20acsesce_VLASS1.1v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0174 seconds
# Time for processing event: 0.0174 seconds
#
# File ia_npy_arrays\ZTF20acsesce_VLASS2.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0645 seconds
# Time for processing event: 0.0645 seconds
#
# File ia_npy_arrays\ZTF20acsesce_VLASS3.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0447 seconds
# Time for processing event: 0.0447 seconds
#
# File ia_npy_arrays\ZTF20acsfdnn_VLASS1.2v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0163 seconds
# Time for processing event: 0.0163 seconds
#
# File ia_npy_arrays\ZTF20acsfdnn_VLASS2.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0196 seconds
# Time for processing event: 0.0196 seconds
#
# File ia_npy_arrays\ZTF20acsfdnn_VLASS3.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0453 seconds
# Time for processing event: 0.0453 seconds
#
# File ia_npy_arrays\ZTF20actddoh_VLASS1.2v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0160 seconds
# Time for processing event: 0.0160 seconds
#
# File ia_npy_arrays\ZTF20actddoh_VLASS2.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0198 seconds
# Time for processing event: 0.0198 seconds
#
# File ia_npy_arrays\ZTF20actddoh_VLASS3.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0456 seconds
# Time for processing event: 0.0466 seconds
#
# Time for file path generation: 0.0000 seconds
# Time for processing event: 0.0010 seconds
#
# File ia_npy_arrays\ZTF20actdeqw_VLASS2.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0188 seconds
# Time for processing event: 0.0188 seconds
#
# File ia_npy_arrays\ZTF20actdeqw_VLASS3.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0480 seconds
# Time for processing event: 0.0490 seconds
#
# File ia_npy_arrays\ZTF20actfeym_VLASS1.1v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0153 seconds
# Time for processing event: 0.0153 seconds
#
# File ia_npy_arrays\ZTF20actfeym_VLASS2.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0185 seconds
# Time for processing event: 0.0185 seconds
#
# File ia_npy_arrays\ZTF20actfeym_VLASS3.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0437 seconds
# Time for processing event: 0.0437 seconds
#
# File ia_npy_arrays\ZTF20actfoxr_VLASS1.1v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0171 seconds
# Time for processing event: 0.0171 seconds
#
# File ia_npy_arrays\ZTF20actfoxr_VLASS2.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0233 seconds
# Time for processing event: 0.0233 seconds
#
# File ia_npy_arrays\ZTF20actfoxr_VLASS3.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0454 seconds
# Time for processing event: 0.0454 seconds
#
# File ia_npy_arrays\ZTF20actiymd_VLASS1.2v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0188 seconds
# Time for processing event: 0.0188 seconds
#
# File ia_npy_arrays\ZTF20actiymd_VLASS2.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0225 seconds
# Time for processing event: 0.0225 seconds
#
# File ia_npy_arrays\ZTF20actiymd_VLASS3.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0467 seconds
# Time for processing event: 0.0467 seconds
#
# File ia_npy_arrays\ZTF20actjbaf_VLASS1.2v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0157 seconds
# Time for processing event: 0.0157 seconds
#
# File ia_npy_arrays\ZTF20actjbaf_VLASS2.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0193 seconds
# Time for processing event: 0.0193 seconds
#
# File ia_npy_arrays\ZTF20actjbaf_VLASS3.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0456 seconds
# Time for processing event: 0.0461 seconds
#
# File ia_npy_arrays\ZTF20actljfs_VLASS1.1v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0158 seconds
# Time for processing event: 0.0158 seconds
#
# File ia_npy_arrays\ZTF20actljfs_VLASS2.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0202 seconds
# Time for processing event: 0.0202 seconds
#
# File ia_npy_arrays\ZTF20actljfs_VLASS3.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0453 seconds
# Time for processing event: 0.0453 seconds
#
# File ia_npy_arrays\ZTF20actlvpy_VLASS1.1v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0145 seconds
# Time for processing event: 0.0145 seconds
#
# File ia_npy_arrays\ZTF20actlvpy_VLASS2.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0195 seconds
# Time for processing event: 0.0205 seconds
#
# File ia_npy_arrays\ZTF20actlvpy_VLASS3.1_array.npy already exists. Skipping save.
# Time for file path generation: 0.0480 seconds
# Time for processing event: 0.0480 seconds
#
# File ia_npy_arrays\ZTF20actoakx_VLASS1.2v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0153 seconds
# Time for processing event: 0.0153 seconds
#
# File ia_npy_arrays\ZTF20actoakx_VLASS2.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0198 seconds
# Time for processing event: 0.0198 seconds
#
# File ia_npy_arrays\ZTF20actoakx_VLASS3.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0492 seconds
# Time for processing event: 0.0492 seconds
#
# File ia_npy_arrays\ZTF20actocyw_VLASS1.2v2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0171 seconds
# Time for processing event: 0.0171 seconds
#
# File ia_npy_arrays\ZTF20actocyw_VLASS2.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0266 seconds
# Time for processing event: 0.0266 seconds
#
# File ia_npy_arrays\ZTF20actocyw_VLASS3.2_array.npy already exists. Skipping save.
# Time for file path generation: 0.0468 seconds
# Time for processing event: 0.0468 seconds
#
# Array saved to ia_npy_arrays\ZTF20actpatx_VLASS1.1v2_array.npy
# Time for file path generation: 0.0178 seconds
# Time for processing event: 0.0178 seconds
#
# Array saved to ia_npy_arrays\ZTF20actpatx_VLASS2.1_array.npy
# Time for file path generation: 0.0192 seconds
# Time for processing event: 0.0192 seconds
#
# Array saved to ia_npy_arrays\ZTF20actpatx_VLASS3.1_array.npy
# Time for file path generation: 0.0469 seconds
# Time for processing event: 0.0482 seconds
#
# Array saved to ia_npy_arrays\ZTF20actpbck_VLASS1.1v2_array.npy
# Time for file path generation: 0.0589 seconds
# Time for processing event: 0.0589 seconds
#
# Array saved to ia_npy_arrays\ZTF20actpbck_VLASS2.1_array.npy
# Time for file path generation: 0.0193 seconds
# Time for processing event: 0.0193 seconds
#
# Array saved to ia_npy_arrays\ZTF20actpbck_VLASS3.1_array.npy
# Time for file path generation: 0.0948 seconds
# Time for processing event: 0.0948 seconds
#
# Array saved to ia_npy_arrays\ZTF20actpuan_VLASS1.2v2_array.npy
# Time for file path generation: 0.0171 seconds
# Time for processing event: 0.0171 seconds
#
# Array saved to ia_npy_arrays\ZTF20actpuan_VLASS2.2_array.npy
# Time for file path generation: 0.0209 seconds
# Time for processing event: 0.0209 seconds
#
# Array saved to ia_npy_arrays\ZTF20actpuan_VLASS3.2_array.npy
# Time for file path generation: 0.0463 seconds
# Time for processing event: 0.0463 seconds
#
# Array saved to ia_npy_arrays\ZTF20actrovz_VLASS1.1v2_array.npy
# Time for file path generation: 0.0162 seconds
# Time for processing event: 0.0162 seconds
#
# Array saved to ia_npy_arrays\ZTF20actrovz_VLASS2.1_array.npy
# Time for file path generation: 0.0208 seconds
# Time for processing event: 0.0208 seconds
#
# Array saved to ia_npy_arrays\ZTF20actrovz_VLASS3.1_array.npy
# Time for file path generation: 0.0453 seconds
# Time for processing event: 0.0453 seconds
#
# Array saved to ia_npy_arrays\ZTF20actrwym_VLASS1.1v2_array.npy
# Time for file path generation: 0.0267 seconds
# Time for processing event: 0.0267 seconds
#
# Array saved to ia_npy_arrays\ZTF20actrwym_VLASS2.1_array.npy
# Time for file path generation: 0.0210 seconds
# Time for processing event: 0.0210 seconds
#
# Array saved to ia_npy_arrays\ZTF20actrwym_VLASS3.1_array.npy
# Time for file path generation: 0.0471 seconds
# Time for processing event: 0.0471 seconds
#
# Array saved to ia_npy_arrays\ZTF20actskcf_VLASS1.1v2_array.npy
# Time for file path generation: 0.0156 seconds
# Time for processing event: 0.0156 seconds
#
# Array saved to ia_npy_arrays\ZTF20actskcf_VLASS2.1_array.npy
# Time for file path generation: 0.0215 seconds
# Time for processing event: 0.0215 seconds
#
# Array saved to ia_npy_arrays\ZTF20actskcf_VLASS3.1_array.npy
# Time for file path generation: 0.0458 seconds
# Time for processing event: 0.0458 seconds
#
# Array saved to ia_npy_arrays\ZTF20actveqm_VLASS1.1v2_array.npy
# Time for file path generation: 0.0611 seconds
# Time for processing event: 0.0611 seconds
#
# Array saved to ia_npy_arrays\ZTF20actveqm_VLASS2.1_array.npy
# Time for file path generation: 0.0226 seconds
# Time for processing event: 0.0226 seconds
#
# Array saved to ia_npy_arrays\ZTF20actveqm_VLASS3.1_array.npy
# Time for file path generation: 0.0503 seconds
# Time for processing event: 0.0503 seconds
#
# Array saved to ia_npy_arrays\ZTF20actvfgr_VLASS1.2v2_array.npy
# Time for file path generation: 0.0207 seconds
# Time for processing event: 0.0207 seconds
#
# Array saved to ia_npy_arrays\ZTF20actvfgr_VLASS2.2_array.npy
# Time for file path generation: 0.0292 seconds
# Time for processing event: 0.0292 seconds
#
# Array saved to ia_npy_arrays\ZTF20actvfgr_VLASS3.2_array.npy
# Time for file path generation: 0.0464 seconds
# Time for processing event: 0.0464 seconds
#
# Array saved to ia_npy_arrays\ZTF20actvlbq_VLASS1.1v2_array.npy
# Time for file path generation: 0.0183 seconds
# Time for processing event: 0.0183 seconds
#
# Array saved to ia_npy_arrays\ZTF20actvlbq_VLASS2.1_array.npy
# Time for file path generation: 0.0221 seconds
# Time for processing event: 0.0221 seconds
#
# Array saved to ia_npy_arrays\ZTF20actvlbq_VLASS3.1_array.npy
# Time for file path generation: 0.0203 seconds
# Time for processing event: 0.0203 seconds
#
# Array saved to ia_npy_arrays\ZTF20actvpyc_VLASS1.1v2_array.npy
# Time for file path generation: 0.0161 seconds
# Time for processing event: 0.0161 seconds
#
# Array saved to ia_npy_arrays\ZTF20actvpyc_VLASS2.1_array.npy
# Time for file path generation: 0.0187 seconds
# Time for processing event: 0.0187 seconds
#
# Array saved to ia_npy_arrays\ZTF20actvpyc_VLASS3.1_array.npy
# Time for file path generation: 0.0453 seconds
# Time for processing event: 0.0466 seconds
#
# Array saved to ia_npy_arrays\ZTF20acucbek_VLASS1.2v2_array.npy
# Time for file path generation: 0.0192 seconds
# Time for processing event: 0.0192 seconds
#
# Array saved to ia_npy_arrays\ZTF20acucbek_VLASS2.2_array.npy
# Time for file path generation: 0.0204 seconds
# Time for processing event: 0.0204 seconds
#
# Array saved to ia_npy_arrays\ZTF20acucbek_VLASS3.2_array.npy
# Time for file path generation: 0.0466 seconds
# Time for processing event: 0.0466 seconds
#
# Array saved to ia_npy_arrays\ZTF20acudkao_VLASS1.1v2_array.npy
# Time for file path generation: 0.0156 seconds
# Time for processing event: 0.0166 seconds
#
# Array saved to ia_npy_arrays\ZTF20acudkao_VLASS2.1_array.npy
# Time for file path generation: 0.0217 seconds
# Time for processing event: 0.0217 seconds
#
# Array saved to ia_npy_arrays\ZTF20acudkao_VLASS3.1_array.npy
# Time for file path generation: 0.0465 seconds
# Time for processing event: 0.0465 seconds
#
# Array saved to ia_npy_arrays\ZTF20acugxbm_VLASS1.2v2_array.npy
# Time for file path generation: 0.0164 seconds
# Time for processing event: 0.0174 seconds
#
# Array saved to ia_npy_arrays\ZTF20acugxbm_VLASS2.2_array.npy
# Time for file path generation: 0.0243 seconds
# Time for processing event: 0.0243 seconds
#
# Array saved to ia_npy_arrays\ZTF20acugxbm_VLASS3.2_array.npy
# Time for file path generation: 0.0453 seconds
# Time for processing event: 0.0453 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuimtq_VLASS1.1v2_array.npy
# Time for file path generation: 0.0195 seconds
# Time for processing event: 0.0195 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuimtq_VLASS2.1_array.npy
# Time for file path generation: 0.0208 seconds
# Time for processing event: 0.0208 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuimtq_VLASS3.1_array.npy
# Time for file path generation: 0.0225 seconds
# Time for processing event: 0.0235 seconds
#
# Array saved to ia_npy_arrays\ZTF20acujaft_VLASS1.1v2_array.npy
# Time for file path generation: 0.0166 seconds
# Time for processing event: 0.0166 seconds
#
# Array saved to ia_npy_arrays\ZTF20acujaft_VLASS2.1_array.npy
# Time for file path generation: 0.0279 seconds
# Time for processing event: 0.0279 seconds
#
# Array saved to ia_npy_arrays\ZTF20acujaft_VLASS3.1_array.npy
# Time for file path generation: 0.0478 seconds
# Time for processing event: 0.0488 seconds
#
# Array saved to ia_npy_arrays\ZTF20acukxat_VLASS1.2v2_array.npy
# Time for file path generation: 0.0164 seconds
# Time for processing event: 0.0174 seconds
#
# Array saved to ia_npy_arrays\ZTF20acukxat_VLASS2.2_array.npy
# Time for file path generation: 0.0192 seconds
# Time for processing event: 0.0192 seconds
#
# Array saved to ia_npy_arrays\ZTF20acukxat_VLASS3.2_array.npy
# Time for file path generation: 0.0466 seconds
# Time for processing event: 0.0466 seconds
#
# Array saved to ia_npy_arrays\ZTF20aculruc_VLASS1.1v2_array.npy
# Time for file path generation: 0.0218 seconds
# Time for processing event: 0.0218 seconds
#
# Array saved to ia_npy_arrays\ZTF20aculruc_VLASS2.1_array.npy
# Time for file path generation: 0.0205 seconds
# Time for processing event: 0.0205 seconds
#
# Array saved to ia_npy_arrays\ZTF20aculruc_VLASS3.1_array.npy
# Time for file path generation: 0.0456 seconds
# Time for processing event: 0.0456 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumcrz_VLASS1.2v2_array.npy
# Time for file path generation: 0.0191 seconds
# Time for processing event: 0.0191 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumcrz_VLASS2.2_array.npy
# Time for file path generation: 0.0209 seconds
# Time for processing event: 0.0209 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumcrz_VLASS3.2_array.npy
# Time for file path generation: 0.1062 seconds
# Time for processing event: 0.1062 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumekm_VLASS1.1v2_array.npy
# Time for file path generation: 0.0216 seconds
# Time for processing event: 0.0216 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumekm_VLASS2.1_array.npy
# Time for file path generation: 0.0279 seconds
# Time for processing event: 0.0279 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumekm_VLASS3.1_array.npy
# Time for file path generation: 0.0473 seconds
# Time for processing event: 0.0473 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumrio_VLASS1.2v2_array.npy
# Time for file path generation: 0.0186 seconds
# Time for processing event: 0.0197 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumrio_VLASS2.2_array.npy
# Time for file path generation: 0.0213 seconds
# Time for processing event: 0.0213 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumrio_VLASS3.2_array.npy
# Time for file path generation: 0.0476 seconds
# Time for processing event: 0.0476 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumxrh_VLASS1.1v2_array.npy
# Time for file path generation: 0.0178 seconds
# Time for processing event: 0.0178 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumxrh_VLASS2.1_array.npy
# Time for file path generation: 0.0216 seconds
# Time for processing event: 0.0216 seconds
#
# Array saved to ia_npy_arrays\ZTF20acumxrh_VLASS3.1_array.npy
# Time for file path generation: 0.0465 seconds
# Time for processing event: 0.0465 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuoacn_VLASS1.2v2_array.npy
# Time for file path generation: 0.0190 seconds
# Time for processing event: 0.0190 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuoacn_VLASS2.2_array.npy
# Time for file path generation: 0.0277 seconds
# Time for processing event: 0.0277 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuoacn_VLASS3.2_array.npy
# Time for file path generation: 0.0469 seconds
# Time for processing event: 0.0469 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuobve_VLASS1.1v2_array.npy
# Time for file path generation: 0.0167 seconds
# Time for processing event: 0.0167 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuobve_VLASS2.1_array.npy
# Time for file path generation: 0.0197 seconds
# Time for processing event: 0.0197 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuobve_VLASS3.1_array.npy
# Time for file path generation: 0.0905 seconds
# Time for processing event: 0.0905 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuoclk_VLASS1.2v2_array.npy
# Time for file path generation: 0.0180 seconds
# Time for processing event: 0.0194 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuoclk_VLASS2.2_array.npy
# Time for file path generation: 0.0359 seconds
# Time for processing event: 0.0369 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuoclk_VLASS3.2_array.npy
# Time for file path generation: 0.0560 seconds
# Time for processing event: 0.0570 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuosvy_VLASS1.2v2_array.npy
# Time for file path generation: 0.0172 seconds
# Time for processing event: 0.0172 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuosvy_VLASS2.2_array.npy
# Time for file path generation: 0.0263 seconds
# Time for processing event: 0.0263 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuosvy_VLASS3.2_array.npy
# Time for file path generation: 0.0451 seconds
# Time for processing event: 0.0451 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuowxj_VLASS1.2v2_array.npy
# Time for file path generation: 0.0182 seconds
# Time for processing event: 0.0182 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuowxj_VLASS2.2_array.npy
# Time for file path generation: 0.0635 seconds
# Time for processing event: 0.0635 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuowxj_VLASS3.2_array.npy
# Time for file path generation: 0.0483 seconds
# Time for processing event: 0.0483 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuoxrx_VLASS1.1v2_array.npy
# Time for file path generation: 0.0175 seconds
# Time for processing event: 0.0175 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuoxrx_VLASS2.1_array.npy
# Time for file path generation: 0.0212 seconds
# Time for processing event: 0.0212 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuoxrx_VLASS3.1_array.npy
# Time for file path generation: 0.0461 seconds
# Time for processing event: 0.0461 seconds
#
# Array saved to ia_npy_arrays\ZTF20acurrzb_VLASS1.2v2_array.npy
# Time for file path generation: 0.0182 seconds
# Time for processing event: 0.0182 seconds
#
# Array saved to ia_npy_arrays\ZTF20acurrzb_VLASS2.2_array.npy
# Time for file path generation: 0.0248 seconds
# Time for processing event: 0.0248 seconds
#
# Array saved to ia_npy_arrays\ZTF20acurrzb_VLASS3.2_array.npy
# Time for file path generation: 0.0446 seconds
# Time for processing event: 0.0460 seconds
#
# Array saved to ia_npy_arrays\ZTF20acurtpj_VLASS1.2v2_array.npy
# Time for file path generation: 0.0173 seconds
# Time for processing event: 0.0173 seconds
#
# Array saved to ia_npy_arrays\ZTF20acurtpj_VLASS2.2_array.npy
# Time for file path generation: 0.0204 seconds
# Time for processing event: 0.0204 seconds
#
# Array saved to ia_npy_arrays\ZTF20acurtpj_VLASS3.2_array.npy
# Time for file path generation: 0.0495 seconds
# Time for processing event: 0.0495 seconds
#
# Array saved to ia_npy_arrays\ZTF20acusneh_VLASS1.1v2_array.npy
# Time for file path generation: 0.0194 seconds
# Time for processing event: 0.0194 seconds
#
# Array saved to ia_npy_arrays\ZTF20acusneh_VLASS2.1_array.npy
# Time for file path generation: 0.0203 seconds
# Time for processing event: 0.0213 seconds
#
# Array saved to ia_npy_arrays\ZTF20acusneh_VLASS3.1_array.npy
# Time for file path generation: 0.0512 seconds
# Time for processing event: 0.0512 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuspji_VLASS1.2v2_array.npy
# Time for file path generation: 0.0191 seconds
# Time for processing event: 0.0191 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuspji_VLASS2.2_array.npy
# Time for file path generation: 0.0234 seconds
# Time for processing event: 0.0234 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuspji_VLASS3.2_array.npy
# Time for file path generation: 0.0474 seconds
# Time for processing event: 0.0474 seconds
#
# Array saved to ia_npy_arrays\ZTF20acusqsp_VLASS1.2v2_array.npy
# Time for file path generation: 0.0169 seconds
# Time for processing event: 0.0169 seconds
#
# Array saved to ia_npy_arrays\ZTF20acusqsp_VLASS2.2_array.npy
# Time for file path generation: 0.0200 seconds
# Time for processing event: 0.0200 seconds
#
# Array saved to ia_npy_arrays\ZTF20acusqsp_VLASS3.2_array.npy
# Time for file path generation: 0.0483 seconds
# Time for processing event: 0.0483 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuvatg_VLASS1.1v2_array.npy
# Time for file path generation: 0.0585 seconds
# Time for processing event: 0.0585 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuvatg_VLASS2.1_array.npy
# Time for file path generation: 0.0215 seconds
# Time for processing event: 0.0215 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuvatg_VLASS3.1_array.npy
# Time for file path generation: 0.0460 seconds
# Time for processing event: 0.0460 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuwwcx_VLASS1.2v2_array.npy
# Time for file path generation: 0.0186 seconds
# Time for processing event: 0.0186 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuwwcx_VLASS2.2_array.npy
# Time for file path generation: 0.0206 seconds
# Time for processing event: 0.0206 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuwwcx_VLASS3.2_array.npy
# Time for file path generation: 0.0484 seconds
# Time for processing event: 0.0484 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuzfpk_VLASS1.1v2_array.npy
# Time for file path generation: 0.0160 seconds
# Time for processing event: 0.0160 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuzfpk_VLASS2.1_array.npy
# Time for file path generation: 0.0207 seconds
# Time for processing event: 0.0207 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuzfpk_VLASS3.1_array.npy
# Time for file path generation: 0.0515 seconds
# Time for processing event: 0.0515 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuzjqk_VLASS1.2v2_array.npy
# Time for file path generation: 0.0179 seconds
# Time for processing event: 0.0179 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuzjqk_VLASS2.2_array.npy
# Time for file path generation: 0.0198 seconds
# Time for processing event: 0.0198 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuzjqk_VLASS3.2_array.npy
# Time for file path generation: 0.0905 seconds
# Time for processing event: 0.0905 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuzlib_VLASS1.1v2_array.npy
# Time for file path generation: 0.0176 seconds
# Time for processing event: 0.0176 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuzlib_VLASS2.1_array.npy
# Time for file path generation: 0.0217 seconds
# Time for processing event: 0.0217 seconds
#
# Array saved to ia_npy_arrays\ZTF20acuzlib_VLASS3.1_array.npy
# Time for file path generation: 0.0475 seconds
# Time for processing event: 0.0475 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvagdq_VLASS1.1v2_array.npy
# Time for file path generation: 0.0191 seconds
# Time for processing event: 0.0191 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvagdq_VLASS2.1_array.npy
# Time for file path generation: 0.0222 seconds
# Time for processing event: 0.0222 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvagdq_VLASS3.1_array.npy
# Time for file path generation: 0.0239 seconds
# Time for processing event: 0.0239 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvbcrd_VLASS1.1v2_array.npy
# Time for file path generation: 0.0161 seconds
# Time for processing event: 0.0161 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvbcrd_VLASS2.1_array.npy
# Time for file path generation: 0.0210 seconds
# Time for processing event: 0.0210 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvbcrd_VLASS3.1_array.npy
# Time for file path generation: 0.0486 seconds
# Time for processing event: 0.0497 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvbrbv_VLASS1.2v2_array.npy
# Time for file path generation: 0.0198 seconds
# Time for processing event: 0.0198 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvbrbv_VLASS2.2_array.npy
# Time for file path generation: 0.0211 seconds
# Time for processing event: 0.0211 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvbrbv_VLASS3.2_array.npy
# Time for file path generation: 0.0497 seconds
# Time for processing event: 0.0497 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvchhw_VLASS1.2v2_array.npy
# Time for file path generation: 0.0177 seconds
# Time for processing event: 0.0177 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvchhw_VLASS2.2_array.npy
# Time for file path generation: 0.0217 seconds
# Time for processing event: 0.0217 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvchhw_VLASS3.2_array.npy
# Time for file path generation: 0.0461 seconds
# Time for processing event: 0.0461 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvdqtg_VLASS1.1v2_array.npy
# Time for file path generation: 0.0210 seconds
# Time for processing event: 0.0210 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvdqtg_VLASS2.1_array.npy
# Time for file path generation: 0.0201 seconds
# Time for processing event: 0.0201 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvdqtg_VLASS3.1_array.npy
# Time for file path generation: 0.0982 seconds
# Time for processing event: 0.0982 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvejem_VLASS1.2v2_array.npy
# Time for file path generation: 0.0189 seconds
# Time for processing event: 0.0189 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvejem_VLASS2.2_array.npy
# Time for file path generation: 0.0199 seconds
# Time for processing event: 0.0199 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvejem_VLASS3.2_array.npy
# Time for file path generation: 0.0451 seconds
# Time for processing event: 0.0451 seconds
#
# Array saved to ia_npy_arrays\ZTF20acviwcr_VLASS1.1v2_array.npy
# Time for file path generation: 0.0162 seconds
# Time for processing event: 0.0162 seconds
#
# Array saved to ia_npy_arrays\ZTF20acviwcr_VLASS2.1_array.npy
# Time for file path generation: 0.0201 seconds
# Time for processing event: 0.0216 seconds
#
# Array saved to ia_npy_arrays\ZTF20acviwcr_VLASS3.1_array.npy
# Time for file path generation: 0.0475 seconds
# Time for processing event: 0.0475 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvkjrm_VLASS1.1v2_array.npy
# Time for file path generation: 0.0165 seconds
# Time for processing event: 0.0165 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvkjrm_VLASS2.1_array.npy
# Time for file path generation: 0.0204 seconds
# Time for processing event: 0.0204 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvkjrm_VLASS3.1_array.npy
# Time for file path generation: 0.0465 seconds
# Time for processing event: 0.0465 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvkqxy_VLASS1.2v2_array.npy
# Time for file path generation: 0.0172 seconds
# Time for processing event: 0.0185 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvkqxy_VLASS2.2_array.npy
# Time for file path generation: 0.0206 seconds
# Time for processing event: 0.0206 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvkqxy_VLASS3.2_array.npy
# Time for file path generation: 0.0460 seconds
# Time for processing event: 0.0460 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvziuf_VLASS1.2v2_array.npy
# Time for file path generation: 0.0171 seconds
# Time for processing event: 0.0171 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvziuf_VLASS2.2_array.npy
# Time for file path generation: 0.0197 seconds
# Time for processing event: 0.0197 seconds
#
# Array saved to ia_npy_arrays\ZTF20acvziuf_VLASS3.2_array.npy
# Time for file path generation: 0.0467 seconds
# Time for processing event: 0.0467 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwcfvx_VLASS1.1v2_array.npy
# Time for file path generation: 0.0589 seconds
# Time for processing event: 0.0589 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwcfvx_VLASS2.1_array.npy
# Time for file path generation: 0.0215 seconds
# Time for processing event: 0.0215 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwcfvx_VLASS3.1_array.npy
# Time for file path generation: 0.0466 seconds
# Time for processing event: 0.0466 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwcqnv_VLASS1.2v2_array.npy
# Time for file path generation: 0.0178 seconds
# Time for processing event: 0.0190 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwcqnv_VLASS2.2_array.npy
# Time for file path generation: 0.0317 seconds
# Time for processing event: 0.0317 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwcqnv_VLASS3.2_array.npy
# Time for file path generation: 0.0491 seconds
# Time for processing event: 0.0491 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwdnbw_VLASS1.2v2_array.npy
# Time for file path generation: 0.0184 seconds
# Time for processing event: 0.0184 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwdnbw_VLASS2.2_array.npy
# Time for file path generation: 0.0203 seconds
# Time for processing event: 0.0203 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwdnbw_VLASS3.2_array.npy
# Time for file path generation: 0.0534 seconds
# Time for processing event: 0.0534 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwetyh_VLASS1.2v2_array.npy
# Time for file path generation: 0.0187 seconds
# Time for processing event: 0.0187 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwetyh_VLASS2.2_array.npy
# Time for file path generation: 0.0638 seconds
# Time for processing event: 0.0638 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwetyh_VLASS3.2_array.npy
# Time for file path generation: 0.0494 seconds
# Time for processing event: 0.0494 seconds
#
# Array saved to ia_npy_arrays\ZTF20acweyro_VLASS1.2v2_array.npy
# Time for file path generation: 0.0180 seconds
# Time for processing event: 0.0180 seconds
#
# Array saved to ia_npy_arrays\ZTF20acweyro_VLASS2.2_array.npy
# Time for file path generation: 0.0212 seconds
# Time for processing event: 0.0212 seconds
#
# Array saved to ia_npy_arrays\ZTF20acweyro_VLASS3.2_array.npy
# Time for file path generation: 0.0462 seconds
# Time for processing event: 0.0462 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfanr_VLASS1.2v2_array.npy
# Time for file path generation: 0.0188 seconds
# Time for processing event: 0.0188 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfanr_VLASS2.2_array.npy
# Time for file path generation: 0.0235 seconds
# Time for processing event: 0.0235 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfanr_VLASS3.2_array.npy
# Time for file path generation: 0.0456 seconds
# Time for processing event: 0.0456 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfcfs_VLASS1.2v2_array.npy
# Time for file path generation: 0.0180 seconds
# Time for processing event: 0.0180 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfcfs_VLASS2.2_array.npy
# Time for file path generation: 0.0226 seconds
# Time for processing event: 0.0226 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfcfs_VLASS3.2_array.npy
# Time for file path generation: 0.0479 seconds
# Time for processing event: 0.0479 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfftd_VLASS1.2v2_array.npy
# Time for file path generation: 0.0219 seconds
# Time for processing event: 0.0219 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfftd_VLASS2.2_array.npy
# Time for file path generation: 0.0372 seconds
# Time for processing event: 0.0372 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfftd_VLASS3.2_array.npy
# Time for file path generation: 0.0605 seconds
# Time for processing event: 0.0605 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfgiy_VLASS1.2v2_array.npy
# Time for file path generation: 0.0188 seconds
# Time for processing event: 0.0188 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfgiy_VLASS2.2_array.npy
# Time for file path generation: 0.0199 seconds
# Time for processing event: 0.0199 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwfgiy_VLASS3.2_array.npy
# Time for file path generation: 0.0466 seconds
# Time for processing event: 0.0466 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwgnxk_VLASS1.2v2_array.npy
# Time for file path generation: 0.0175 seconds
# Time for processing event: 0.0175 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwgnxk_VLASS2.2_array.npy
# Time for file path generation: 0.0224 seconds
# Time for processing event: 0.0224 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwgnxk_VLASS3.2_array.npy
# Time for file path generation: 0.0477 seconds
# Time for processing event: 0.0477 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwijiy_VLASS1.1v2_array.npy
# Time for file path generation: 0.0159 seconds
# Time for processing event: 0.0159 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwijiy_VLASS2.1_array.npy
# Time for file path generation: 0.0208 seconds
# Time for processing event: 0.0208 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwijiy_VLASS3.1_array.npy
# Time for file path generation: 0.0469 seconds
# Time for processing event: 0.0469 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwkvgj_VLASS1.2v2_array.npy
# Time for file path generation: 0.0182 seconds
# Time for processing event: 0.0182 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwkvgj_VLASS2.2_array.npy
# Time for file path generation: 0.0193 seconds
# Time for processing event: 0.0193 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwkvgj_VLASS3.2_array.npy
# Time for file path generation: 0.0437 seconds
# Time for processing event: 0.0437 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwkwqn_VLASS1.2v2_array.npy
# Time for file path generation: 0.0180 seconds
# Time for processing event: 0.0180 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwkwqn_VLASS2.2_array.npy
# Time for file path generation: 0.0195 seconds
# Time for processing event: 0.0195 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwkwqn_VLASS3.2_array.npy
# Time for file path generation: 0.0501 seconds
# Time for processing event: 0.0501 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwmpsj_VLASS1.1v2_array.npy
# Time for file path generation: 0.0173 seconds
# Time for processing event: 0.0173 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwmpsj_VLASS2.1_array.npy
# Time for file path generation: 0.0204 seconds
# Time for processing event: 0.0204 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwmpsj_VLASS3.1_array.npy
# Time for file path generation: 0.0463 seconds
# Time for processing event: 0.0463 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwncbd_VLASS1.2v2_array.npy
# Time for file path generation: 0.0526 seconds
# Time for processing event: 0.0526 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwncbd_VLASS2.2_array.npy
# Time for file path generation: 0.0196 seconds
# Time for processing event: 0.0196 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwncbd_VLASS3.2_array.npy
# Time for file path generation: 0.0456 seconds
# Time for processing event: 0.0468 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwnrty_VLASS1.2v2_array.npy
# Time for file path generation: 0.0191 seconds
# Time for processing event: 0.0191 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwnrty_VLASS2.2_array.npy
# Time for file path generation: 0.0217 seconds
# Time for processing event: 0.0217 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwnrty_VLASS3.2_array.npy
# Time for file path generation: 0.0486 seconds
# Time for processing event: 0.0486 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwoamm_VLASS1.2v2_array.npy
# Time for file path generation: 0.0193 seconds
# Time for processing event: 0.0193 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwoamm_VLASS2.2_array.npy
# Time for file path generation: 0.0230 seconds
# Time for processing event: 0.0230 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwoamm_VLASS3.2_array.npy
# Time for file path generation: 0.0498 seconds
# Time for processing event: 0.0498 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwomqh_VLASS1.2v2_array.npy
# Time for file path generation: 0.0178 seconds
# Time for processing event: 0.0178 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwomqh_VLASS2.2_array.npy
# Time for file path generation: 0.0202 seconds
# Time for processing event: 0.0202 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwomqh_VLASS3.2_array.npy
# Time for file path generation: 0.0492 seconds
# Time for processing event: 0.0492 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwozwz_VLASS1.1v2_array.npy
# Time for file path generation: 0.0165 seconds
# Time for processing event: 0.0165 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwozwz_VLASS2.1_array.npy
# Time for file path generation: 0.0191 seconds
# Time for processing event: 0.0191 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwozwz_VLASS3.1_array.npy
# Time for file path generation: 0.0812 seconds
# Time for processing event: 0.0812 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpaov_VLASS1.1v2_array.npy
# Time for file path generation: 0.0173 seconds
# Time for processing event: 0.0173 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpaov_VLASS2.1_array.npy
# Time for file path generation: 0.0204 seconds
# Time for processing event: 0.0204 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpaov_VLASS3.1_array.npy
# Time for file path generation: 0.0476 seconds
# Time for processing event: 0.0476 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpbgv_VLASS1.2v2_array.npy
# Time for file path generation: 0.0190 seconds
# Time for processing event: 0.0190 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpbgv_VLASS2.2_array.npy
# Time for file path generation: 0.0428 seconds
# Time for processing event: 0.0428 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpbgv_VLASS3.2_array.npy
# Time for file path generation: 0.0484 seconds
# Time for processing event: 0.0484 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpfvq_VLASS1.2v2_array.npy
# Time for file path generation: 0.0184 seconds
# Time for processing event: 0.0184 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpfvq_VLASS2.2_array.npy
# Time for file path generation: 0.0217 seconds
# Time for processing event: 0.0217 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpfvq_VLASS3.2_array.npy
# Time for file path generation: 0.0536 seconds
# Time for processing event: 0.0547 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwphqb_VLASS1.2v2_array.npy
# Time for file path generation: 0.0221 seconds
# Time for processing event: 0.0221 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwphqb_VLASS2.2_array.npy
# Time for file path generation: 0.0228 seconds
# Time for processing event: 0.0228 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwphqb_VLASS3.2_array.npy
# Time for file path generation: 0.0492 seconds
# Time for processing event: 0.0492 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpixx_VLASS1.1v2_array.npy
# Time for file path generation: 0.0205 seconds
# Time for processing event: 0.0205 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpixx_VLASS2.1_array.npy
# Time for file path generation: 0.0281 seconds
# Time for processing event: 0.0281 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwpixx_VLASS3.1_array.npy
# Time for file path generation: 0.0587 seconds
# Time for processing event: 0.0587 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqjaw_VLASS1.2v2_array.npy
# Time for file path generation: 0.0452 seconds
# Time for processing event: 0.0452 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqjaw_VLASS2.2_array.npy
# Time for file path generation: 0.0293 seconds
# Time for processing event: 0.0293 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqjaw_VLASS3.2_array.npy
# Time for file path generation: 0.0757 seconds
# Time for processing event: 0.0757 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqkuz_VLASS1.1v2_array.npy
# Time for file path generation: 0.0243 seconds
# Time for processing event: 0.0243 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqkuz_VLASS2.1_array.npy
# Time for file path generation: 0.0243 seconds
# Time for processing event: 0.0254 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqkuz_VLASS3.1_array.npy
# Time for file path generation: 0.0602 seconds
# Time for processing event: 0.0615 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqlpq_VLASS1.1v2_array.npy
# Time for file path generation: 0.0284 seconds
# Time for processing event: 0.0284 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqlpq_VLASS2.1_array.npy
# Time for file path generation: 0.0283 seconds
# Time for processing event: 0.0293 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqlpq_VLASS3.1_array.npy
# Time for file path generation: 0.0561 seconds
# Time for processing event: 0.0571 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqndp_VLASS1.2v2_array.npy
# Time for file path generation: 0.0188 seconds
# Time for processing event: 0.0188 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqndp_VLASS2.2_array.npy
# Time for file path generation: 0.0217 seconds
# Time for processing event: 0.0217 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwqndp_VLASS3.2_array.npy
# Time for file path generation: 0.0481 seconds
# Time for processing event: 0.0481 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwujgz_VLASS1.1v2_array.npy
# Time for file path generation: 0.0183 seconds
# Time for processing event: 0.0183 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwujgz_VLASS2.1_array.npy
# Time for file path generation: 0.0260 seconds
# Time for processing event: 0.0260 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwujgz_VLASS3.1_array.npy
# Time for file path generation: 0.0500 seconds
# Time for processing event: 0.0500 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwxbyr_VLASS1.1v2_array.npy
# Time for file path generation: 0.0170 seconds
# Time for processing event: 0.0170 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwxbyr_VLASS2.1_array.npy
# Time for file path generation: 0.0203 seconds
# Time for processing event: 0.0203 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwxbyr_VLASS3.1_array.npy
# Time for file path generation: 0.0478 seconds
# Time for processing event: 0.0478 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwyihb_VLASS1.1v2_array.npy
# Time for file path generation: 0.0265 seconds
# Time for processing event: 0.0265 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwyihb_VLASS2.1_array.npy
# Time for file path generation: 0.0225 seconds
# Time for processing event: 0.0225 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwyihb_VLASS3.1_array.npy
# Time for file path generation: 0.0493 seconds
# Time for processing event: 0.0503 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwyoxc_VLASS1.1v2_array.npy
# Time for file path generation: 0.0257 seconds
# Time for processing event: 0.0257 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwyoxc_VLASS2.1_array.npy
# Time for file path generation: 0.0200 seconds
# Time for processing event: 0.0200 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwyoxc_VLASS3.1_array.npy
# Time for file path generation: 0.0461 seconds
# Time for processing event: 0.0461 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwytmh_VLASS1.1v2_array.npy
# Time for file path generation: 0.0158 seconds
# Time for processing event: 0.0158 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwytmh_VLASS2.1_array.npy
# Time for file path generation: 0.0213 seconds
# Time for processing event: 0.0225 seconds
#
# Array saved to ia_npy_arrays\ZTF20acwytmh_VLASS3.1_array.npy
# Time for file path generation: 0.0901 seconds
# Time for processing event: 0.0901 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxbbaj_VLASS1.1v2_array.npy
# Time for file path generation: 0.0165 seconds
# Time for processing event: 0.0175 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxbbaj_VLASS2.1_array.npy
# Time for file path generation: 0.0211 seconds
# Time for processing event: 0.0221 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxbbaj_VLASS3.1_array.npy
# Time for file path generation: 0.0468 seconds
# Time for processing event: 0.0468 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxbnjd_VLASS1.1v2_array.npy
# Time for file path generation: 0.0243 seconds
# Time for processing event: 0.0243 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxbnjd_VLASS2.1_array.npy
# Time for file path generation: 0.0264 seconds
# Time for processing event: 0.0264 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxbnjd_VLASS3.1_array.npy
# Time for file path generation: 0.0522 seconds
# Time for processing event: 0.0522 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxcxkz_VLASS1.1v2_array.npy
# Time for file path generation: 0.0202 seconds
# Time for processing event: 0.0202 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxcxkz_VLASS2.1_array.npy
# Time for file path generation: 0.0237 seconds
# Time for processing event: 0.0237 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxcxkz_VLASS3.1_array.npy
# Time for file path generation: 0.0494 seconds
# Time for processing event: 0.0494 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxdawc_VLASS1.2v2_array.npy
# Time for file path generation: 0.0181 seconds
# Time for processing event: 0.0181 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxdawc_VLASS2.2_array.npy
# Time for file path generation: 0.0206 seconds
# Time for processing event: 0.0206 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxdawc_VLASS3.2_array.npy
# Time for file path generation: 0.0459 seconds
# Time for processing event: 0.0459 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxkxxr_VLASS1.1v2_array.npy
# Time for file path generation: 0.0167 seconds
# Time for processing event: 0.0178 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxkxxr_VLASS2.1_array.npy
# Time for file path generation: 0.0225 seconds
# Time for processing event: 0.0225 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxkxxr_VLASS3.1_array.npy
# Time for file path generation: 0.0967 seconds
# Time for processing event: 0.0967 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxlaih_VLASS1.1v2_array.npy
# Time for file path generation: 0.0214 seconds
# Time for processing event: 0.0224 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxlaih_VLASS2.1_array.npy
# Time for file path generation: 0.0371 seconds
# Time for processing event: 0.0371 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxlaih_VLASS3.1_array.npy
# Time for file path generation: 0.0630 seconds
# Time for processing event: 0.0630 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxmxth_VLASS1.1v2_array.npy
# Time for file path generation: 0.0183 seconds
# Time for processing event: 0.0193 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxmxth_VLASS2.1_array.npy
# Time for file path generation: 0.0222 seconds
# Time for processing event: 0.0222 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxmxth_VLASS3.1_array.npy
# Time for file path generation: 0.0507 seconds
# Time for processing event: 0.0507 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxnafa_VLASS1.2v2_array.npy
# Time for file path generation: 0.0206 seconds
# Time for processing event: 0.0217 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxnafa_VLASS2.2_array.npy
# Time for file path generation: 0.0195 seconds
# Time for processing event: 0.0195 seconds
#
# Array saved to ia_npy_arrays\ZTF20acxnafa_VLASS3.2_array.npy
# Time for file path generation: 0.0474 seconds
# Time for processing event: 0.0474 seconds
#
# Dataframe written to: ia_supernovae_with_file_path.csv
# Total time for all events: 9.6469 seconds
#               Name  Ra_hourangle  Dec_degree     Epoch        Date  \
# 0     ZTF18aahfbqp     10.445233   21.723917  VLASS1.2  2019-04-18
# 1     ZTF18aahfbqp     10.445233   21.723917  VLASS2.2  2021-12-01
# 2     ZTF18aahfbqp     10.445233   21.723917  VLASS3.2  2024-04-29
# 3     ZTF18aahfeiy     10.287656   43.523361  VLASS1.2  2019-05-25
# 4     ZTF18aahfeiy     10.287656   43.523361  VLASS2.2  2021-10-09
# ...            ...           ...         ...       ...         ...
# 9091  ZTF20acxmxth     23.194092    7.780361  VLASS2.1  2020-08-12
# 9092  ZTF20acxmxth     23.194092    7.780361  VLASS3.1  2023-03-07
# 9093  ZTF20acxnafa     23.065981   30.724000  VLASS1.2  2019-06-09
# 9094  ZTF20acxnafa     23.065981   30.724000  VLASS2.2  2021-12-03
# 9095  ZTF20acxnafa     23.065981   30.724000  VLASS3.2  2024-05-21
#
#                                             File_path
# 0     ia_npy_arrays\ZTF18aahfbqp_VLASS1.2v2_array.npy
# 1       ia_npy_arrays\ZTF18aahfbqp_VLASS2.2_array.npy
# 2       ia_npy_arrays\ZTF18aahfbqp_VLASS3.2_array.npy
# 3     ia_npy_arrays\ZTF18aahfeiy_VLASS1.2v2_array.npy
# 4       ia_npy_arrays\ZTF18aahfeiy_VLASS2.2_array.npy
# ...                                               ...
# 9091    ia_npy_arrays\ZTF20acxmxth_VLASS2.1_array.npy
# 9092    ia_npy_arrays\ZTF20acxmxth_VLASS3.1_array.npy
# 9093  ia_npy_arrays\ZTF20acxnafa_VLASS1.2v2_array.npy
# 9094    ia_npy_arrays\ZTF20acxnafa_VLASS2.2_array.npy
# 9095    ia_npy_arrays\ZTF20acxnafa_VLASS3.2_array.npy
#
# [9096 rows x 6 columns]

# %% [markdown]
# Order of Operations:
# - Clear old batch_fits folder contents
# - Make new batch file with renew_batch_file
# - Go to Cirada and get batch file
#     - Move contents to batch_fits
# - Use batch_update_csv to update csv

# %%
file_path = "ia_supernovae_stuff/ia_full_data/ia_supernovae.csv"
ia_supernovae_df = pd.read_csv(file_path)
test_df = ia_supernovae_df.iloc[1350:1450]
primed_event_list = extract_epoch_number(assign_indices(multiple_objects_to_event_list(test_df)))
kobe = match_files_to_data(primed_event_list, "batch_fits")

# %%
n = 4
centered_check_image(kobe[n]['Matched_File'],
            kobe[n]['Epoch'],
            kobe[n]['c'],
            'hello')

kobe[n]['Name']
# Out:
# Cutout centered at position 74.96183333333333, 21.360222222222223
# 'ZTF19abmqasg'

# %%
update_csv(700, 750)
# Out:
# Downloading VLASS1.1.ql.T19t18.J134812+353000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T19t18.J134812+353000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acwyowc_VLASS1.1v2_array.npy
# Time for file path generation: 170.6517 seconds
# Time for processing event: 170.6517 seconds
#
# Downloading VLASS2.1.ql.T19t18.J134812+353000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T19t18.J134812+353000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acwyowc_VLASS2.1_array.npy
# Time for file path generation: 52.7164 seconds
# Time for processing event: 52.7164 seconds
#
# Downloading VLASS3.1.ql.T19t18.J134812+353000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T19t18.J134812+353000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acwyowc_VLASS3.1_array.npy
# Time for file path generation: 29.5584 seconds
# Time for processing event: 29.5597 seconds
#
# Downloading VLASS1.2.ql.T14t21.J134647+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T14t21.J134647+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acwyqeg_VLASS1.2v2_array.npy
# Time for file path generation: 29.6013 seconds
# Time for processing event: 29.6013 seconds
#
# Downloading VLASS2.2.ql.T14t21.J134647+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T14t21.J134647+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acwyqeg_VLASS2.2_array.npy
# Time for file path generation: 13.3213 seconds
# Time for processing event: 13.3213 seconds
#
# Downloading VLASS3.2.ql.T14t21.J134647+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T14t21.J134647+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acwyqeg_VLASS3.2_array.npy
# Time for file path generation: 16.7041 seconds
# Time for processing event: 16.7041 seconds
#
# Downloading VLASS1.1.ql.T11t18.J115801+033000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T11t18.J115801+033000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxbksd_VLASS1.1v2_array.npy
# Time for file path generation: 19.8227 seconds
# Time for processing event: 19.8237 seconds
#
# Downloading VLASS2.1.ql.T11t18.J115801+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T11t18.J115801+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxbksd_VLASS2.1_array.npy
# Time for file path generation: 19.3149 seconds
# Time for processing event: 19.3161 seconds
#
# Downloading VLASS3.1.ql.T11t18.J115801+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T11t18.J115801+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxbksd_VLASS3.1_array.npy
# Time for file path generation: 27.7462 seconds
# Time for processing event: 27.7474 seconds
#
# Downloading VLASS1.1.ql.T06t08.J045024-163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T06t08.J045024-163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxhvkv_VLASS1.1v2_array.npy
# Time for file path generation: 16.7213 seconds
# Time for processing event: 16.7223 seconds
#
# Downloading VLASS2.1.ql.T06t08.J045024-163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T06t08.J045024-163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxhvkv_VLASS2.1_array.npy
# Time for file path generation: 13.7935 seconds
# Time for processing event: 13.7935 seconds
#
# Downloading VLASS3.1.ql.T06t08.J045024-163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T06t08.J045024-163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxhvkv_VLASS3.1_array.npy
# Time for file path generation: 13.2549 seconds
# Time for processing event: 13.2549 seconds
#
# Downloading VLASS1.2.ql.T17t02.J005556+243000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T17t02.J005556+243000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxijqw_VLASS1.2v2_array.npy
# Time for file path generation: 13.4963 seconds
# Time for processing event: 13.4978 seconds
#
# Downloading VLASS2.2.ql.T17t02.J005556+243000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T17t02.J005556+243000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxijqw_VLASS2.2_array.npy
# Time for file path generation: 35.9996 seconds
# Time for processing event: 35.9996 seconds
#
# Downloading VLASS3.2.ql.T17t02.J005556+243000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T17t02.J005556+243000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxijqw_VLASS3.2_array.npy
# Time for file path generation: 18.4349 seconds
# Time for processing event: 18.4349 seconds
#
# Downloading VLASS1.2.ql.T08t13.J083017-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T08t13.J083017-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxwtyx_VLASS1.2v2_array.npy
# Time for file path generation: 18.4825 seconds
# Time for processing event: 18.4825 seconds
#
# Downloading VLASS2.2.ql.T08t13.J083017-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T08t13.J083017-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxwtyx_VLASS2.2_array.npy
# Time for file path generation: 15.8256 seconds
# Time for processing event: 15.8256 seconds
#
# Downloading VLASS3.2.ql.T08t13.J083017-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T08t13.J083017-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxwtyx_VLASS3.2_array.npy
# Time for file path generation: 17.6632 seconds
# Time for processing event: 17.6632 seconds
#
# Downloading VLASS1.2.ql.T21t09.J080241+423000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T21t09.J080241+423000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxyarg_VLASS1.2v2_array.npy
# Time for file path generation: 19.5643 seconds
# Time for processing event: 19.5643 seconds
#
# Downloading VLASS2.2.ql.T21t09.J080241+423000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T21t09.J080241+423000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxyarg_VLASS2.2_array.npy
# Time for file path generation: 20.1079 seconds
# Time for processing event: 20.1079 seconds
#
# Downloading VLASS3.2.ql.T21t09.J080241+423000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T21t09.J080241+423000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acxyarg_VLASS3.2_array.npy
# Time for file path generation: 19.8328 seconds
# Time for processing event: 19.8328 seconds
#
# Downloading VLASS1.1.ql.T24t15.J145513+523000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T24t15.J145513+523000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyarki_VLASS1.1v2_array.npy
# Time for file path generation: 15.9423 seconds
# Time for processing event: 15.9444 seconds
#
# Downloading VLASS2.1.ql.T24t15.J145513+523000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T24t15.J145513+523000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyarki_VLASS2.1_array.npy
# Time for file path generation: 31.7915 seconds
# Time for processing event: 31.7915 seconds
#
# Downloading VLASS3.1.ql.T24t15.J145513+523000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T24t15.J145513+523000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyarki_VLASS3.1_array.npy
# Time for file path generation: 61.5718 seconds
# Time for processing event: 61.5718 seconds
#
# Downloading VLASS1.2.ql.T09t17.J105001-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T09t17.J105001-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyawjf_VLASS1.2v2_array.npy
# Time for file path generation: 16.7511 seconds
# Time for processing event: 16.7511 seconds
#
# Downloading VLASS2.2.ql.T09t17.J105001-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T09t17.J105001-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyawjf_VLASS2.2_array.npy
# Time for file path generation: 15.1298 seconds
# Time for processing event: 15.1298 seconds
#
# Downloading VLASS3.2.ql.T09t17.J105001-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T09t17.J105001-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyawjf_VLASS3.2_array.npy
# Time for file path generation: 14.3772 seconds
# Time for processing event: 14.3782 seconds
#
# Downloading VLASS1.2.ql.T19t15.J114321+343000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T19t15.J114321+343000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acybdar_VLASS1.2v2_array.npy
# Time for file path generation: 24.1389 seconds
# Time for processing event: 24.1403 seconds
#
# Downloading VLASS2.2.ql.T19t15.J114321+343000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T19t15.J114321+343000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acybdar_VLASS2.2_array.npy
# Time for file path generation: 35.4672 seconds
# Time for processing event: 35.4672 seconds
#
# Downloading VLASS3.2.ql.T19t15.J114321+343000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T19t15.J114321+343000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acybdar_VLASS3.2_array.npy
# Time for file path generation: 19.5302 seconds
# Time for processing event: 19.5302 seconds
#
# Downloading VLASS1.1.ql.T18t19.J140019+313000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T18t19.J140019+313000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyctqi_VLASS1.1v2_array.npy
# Time for file path generation: 64.2186 seconds
# Time for processing event: 64.2186 seconds
#
# Downloading VLASS2.1.ql.T18t19.J140019+313000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T18t19.J140019+313000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyctqi_VLASS2.1_array.npy
# Time for file path generation: 28.8133 seconds
# Time for processing event: 28.8133 seconds
#
# Downloading VLASS3.1.ql.T18t19.J140019+313000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T18t19.J140019+313000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyctqi_VLASS3.1_array.npy
# Time for file path generation: 16.1778 seconds
# Time for processing event: 16.1789 seconds
#
# Downloading VLASS1.1.ql.T16t20.J144314+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T16t20.J144314+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acydlux_VLASS1.1v2_array.npy
# Time for file path generation: 16.6798 seconds
# Time for processing event: 16.6798 seconds
#
# Downloading VLASS2.1.ql.T16t20.J144314+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T16t20.J144314+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acydlux_VLASS2.1_array.npy
# Time for file path generation: 16.1311 seconds
# Time for processing event: 16.1311 seconds
#
# Downloading VLASS3.1.ql.T16t20.J144314+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T16t20.J144314+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acydlux_VLASS3.1_array.npy
# Time for file path generation: 24.7690 seconds
# Time for processing event: 24.7690 seconds
#
# ia_fits\VLASS1.1.ql.T10t01.J003000-003000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits already exists. Skipping download.
# Array saved to ia_npy_arrays\ZTF18acynmcp_VLASS1.1v2_array.npy
# Time for file path generation: 2.7301 seconds
# Time for processing event: 2.7313 seconds
#
# ia_fits\VLASS2.1.ql.T10t01.J003000-003000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits already exists. Skipping download.
# Array saved to ia_npy_arrays\ZTF18acynmcp_VLASS2.1_array.npy
# Time for file path generation: 2.5638 seconds
# Time for processing event: 2.5649 seconds
#
# ia_fits\VLASS3.1.ql.T10t01.J003000-003000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits already exists. Skipping download.
# Array saved to ia_npy_arrays\ZTF18acynmcp_VLASS3.1_array.npy
# Time for file path generation: 3.1963 seconds
# Time for processing event: 3.1963 seconds
#
# Downloading VLASS1.1.ql.T11t01.J002602+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T11t01.J002602+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acynoro_VLASS1.1v2_array.npy
# Time for file path generation: 39.5013 seconds
# Time for processing event: 39.5013 seconds
#
# Downloading VLASS2.1.ql.T11t01.J002602+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T11t01.J002602+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acynoro_VLASS2.1_array.npy
# Time for file path generation: 43.6113 seconds
# Time for processing event: 43.6113 seconds
#
# Downloading VLASS3.1.ql.T11t01.J002602+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T11t01.J002602+033000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acynoro_VLASS3.1_array.npy
# Time for file path generation: 24.3523 seconds
# Time for processing event: 24.3523 seconds
#
# Downloading VLASS1.1.ql.T16t22.J161240+203000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T16t22.J161240+203000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyyhgi_VLASS1.1v2_array.npy
# Time for file path generation: 17.3095 seconds
# Time for processing event: 17.3095 seconds
#
# Downloading VLASS2.1.ql.T16t22.J161240+203000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T16t22.J161240+203000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyyhgi_VLASS2.1_array.npy
# Time for file path generation: 17.9399 seconds
# Time for processing event: 17.9399 seconds
#
# Downloading VLASS3.1.ql.T16t22.J161240+203000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T16t22.J161240+203000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18acyyhgi_VLASS3.1_array.npy
# Time for file path generation: 19.3937 seconds
# Time for processing event: 19.3937 seconds
#
# Downloading VLASS1.2.ql.T18t32.J233051+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T18t32.J233051+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczbgpm_VLASS1.2v2_array.npy
# Time for file path generation: 15.6385 seconds
# Time for processing event: 15.6385 seconds
#
# Downloading VLASS2.2.ql.T18t32.J233051+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T18t32.J233051+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczbgpm_VLASS2.2_array.npy
# Time for file path generation: 15.2005 seconds
# Time for processing event: 15.2005 seconds
#
# Downloading VLASS3.2.ql.T18t32.J233051+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T18t32.J233051+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczbgpm_VLASS3.2_array.npy
# Time for file path generation: 18.0067 seconds
# Time for processing event: 18.0067 seconds
#
# Downloading VLASS1.1.ql.T30t05.J125615+793000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T30t05.J125615+793000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczdetm_VLASS1.1v2_array.npy
# Time for file path generation: 14.6087 seconds
# Time for processing event: 14.6097 seconds
#
# Downloading VLASS2.1.ql.T30t05.J125615+793000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T30t05.J125615+793000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczdetm_VLASS2.1_array.npy
# Time for file path generation: 16.2842 seconds
# Time for processing event: 16.2842 seconds
#
# Downloading VLASS3.1.ql.T30t05.J125615+793000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T30t05.J125615+793000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczdetm_VLASS3.1_array.npy
# Time for file path generation: 15.1205 seconds
# Time for processing event: 15.1205 seconds
#
# Downloading VLASS1.2.ql.T09t15.J093402-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T09t15.J093402-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczdtgn_VLASS1.2v2_array.npy
# Time for file path generation: 16.0418 seconds
# Time for processing event: 16.0433 seconds
#
# Downloading VLASS2.2.ql.T09t15.J093402-043000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T09t15.J093402-043000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczdtgn_VLASS2.2_array.npy
# Time for file path generation: 15.9644 seconds
# Time for processing event: 15.9644 seconds
#
# Downloading VLASS3.2.ql.T09t15.J093402-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T09t15.J093402-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczdtgn_VLASS3.2_array.npy
# Time for file path generation: 15.5111 seconds
# Time for processing event: 15.5111 seconds
#
# Downloading VLASS1.1.ql.T23t15.J143851+483000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T23t15.J143851+483000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczeesl_VLASS1.1v2_array.npy
# Time for file path generation: 17.3211 seconds
# Time for processing event: 17.3211 seconds
#
# Downloading VLASS2.1.ql.T23t15.J143851+483000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T23t15.J143851+483000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczeesl_VLASS2.1_array.npy
# Time for file path generation: 18.2578 seconds
# Time for processing event: 18.2578 seconds
#
# Downloading VLASS3.1.ql.T23t15.J143851+483000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T23t15.J143851+483000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczeesl_VLASS3.1_array.npy
# Time for file path generation: 14.9546 seconds
# Time for processing event: 14.9546 seconds
#
# Downloading VLASS1.2.ql.T13t22.J143810+083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T13t22.J143810+083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczemzj_VLASS1.2v2_array.npy
# Time for file path generation: 26.9181 seconds
# Time for processing event: 26.9193 seconds
#
# Downloading VLASS2.2.ql.T13t22.J143810+083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T13t22.J143810+083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczemzj_VLASS2.2_array.npy
# Time for file path generation: 15.0725 seconds
# Time for processing event: 15.0725 seconds
#
# Downloading VLASS3.2.ql.T13t22.J143810+083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T13t22.J143810+083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczemzj_VLASS3.2_array.npy
# Time for file path generation: 16.8174 seconds
# Time for processing event: 16.8185 seconds
#
# Downloading VLASS1.2.ql.T17t15.J105441+273000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T17t15.J105441+273000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczenvx_VLASS1.2v2_array.npy
# Time for file path generation: 30.5288 seconds
# Time for processing event: 30.5300 seconds
#
# Downloading VLASS2.2.ql.T17t15.J105441+273000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T17t15.J105441+273000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczenvx_VLASS2.2_array.npy
# Time for file path generation: 21.3085 seconds
# Time for processing event: 21.3085 seconds
#
# Downloading VLASS3.2.ql.T17t15.J105441+273000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T17t15.J105441+273000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczenvx_VLASS3.2_array.npy
# Time for file path generation: 23.5552 seconds
# Time for processing event: 23.5552 seconds
#
# Downloading VLASS1.1.ql.T07t02.J005418-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T07t02.J005418-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczotxi_VLASS1.1v2_array.npy
# Time for file path generation: 19.0584 seconds
# Time for processing event: 19.0584 seconds
#
# Downloading VLASS2.1.ql.T07t02.J005418-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T07t02.J005418-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczotxi_VLASS2.1_array.npy
# Time for file path generation: 19.7366 seconds
# Time for processing event: 19.7366 seconds
#
# Downloading VLASS3.1.ql.T07t02.J005418-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T07t02.J005418-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczotxi_VLASS3.1_array.npy
# Time for file path generation: 31.6311 seconds
# Time for processing event: 31.6311 seconds
#
# Downloading VLASS1.1.ql.T07t02.J011824-123000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T07t02.J011824-123000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczpgmi_VLASS1.1v2_array.npy
# Time for file path generation: 16.8221 seconds
# Time for processing event: 16.8221 seconds
#
# Downloading VLASS2.1.ql.T07t02.J011824-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T07t02.J011824-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczpgmi_VLASS2.1_array.npy
# Time for file path generation: 16.1378 seconds
# Time for processing event: 16.1378 seconds
#
# Downloading VLASS3.1.ql.T07t02.J011824-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T07t02.J011824-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczpgmi_VLASS3.1_array.npy
# Time for file path generation: 15.7502 seconds
# Time for processing event: 15.7514 seconds
#
# Downloading VLASS1.2.ql.T17t05.J033306+253000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T17t05.J033306+253000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczqtpt_VLASS1.2v2_array.npy
# Time for file path generation: 17.0316 seconds
# Time for processing event: 17.0316 seconds
#
# Downloading VLASS2.2.ql.T17t05.J033306+253000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T17t05.J033306+253000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczqtpt_VLASS2.2_array.npy
# Time for file path generation: 22.7269 seconds
# Time for processing event: 22.7269 seconds
#
# Downloading VLASS3.2.ql.T17t05.J033306+253000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T17t05.J033306+253000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczqtpt_VLASS3.2_array.npy
# Time for file path generation: 20.1360 seconds
# Time for processing event: 20.1371 seconds
#
# Downloading VLASS1.2.ql.T18t30.J214715+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T18t30.J214715+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczzrkn_VLASS1.2v2_array.npy
# Time for file path generation: 15.5952 seconds
# Time for processing event: 15.5963 seconds
#
# Downloading VLASS2.2.ql.T18t30.J214715+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T18t30.J214715+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczzrkn_VLASS2.2_array.npy
# Time for file path generation: 25.6748 seconds
# Time for processing event: 25.6748 seconds
#
# Downloading VLASS3.2.ql.T18t30.J214715+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T18t30.J214715+283000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18aczzrkn_VLASS3.2_array.npy
# Time for file path generation: 16.7684 seconds
# Time for processing event: 16.7684 seconds
#
# Downloading VLASS1.1.ql.T11t02.J011400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T11t02.J011400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaadmh_VLASS1.1v2_array.npy
# Time for file path generation: 15.8780 seconds
# Time for processing event: 15.8780 seconds
#
# Downloading VLASS2.1.ql.T11t02.J011400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T11t02.J011400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaadmh_VLASS2.1_array.npy
# Time for file path generation: 14.7889 seconds
# Time for processing event: 14.7889 seconds
#
# Downloading VLASS3.1.ql.T11t02.J011400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T11t02.J011400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaadmh_VLASS3.1_array.npy
# Time for file path generation: 14.1898 seconds
# Time for processing event: 14.1898 seconds
#
# Downloading VLASS1.1.ql.T07t09.J054229-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T07t09.J054229-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaifep_VLASS1.1v2_array.npy
# Time for file path generation: 16.8105 seconds
# Time for processing event: 16.8105 seconds
#
# Downloading VLASS2.1.ql.T07t09.J054229-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T07t09.J054229-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaifep_VLASS2.1_array.npy
# Time for file path generation: 19.6758 seconds
# Time for processing event: 19.6758 seconds
#
# Downloading VLASS3.1.ql.T07t09.J054229-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T07t09.J054229-123000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaifep_VLASS3.1_array.npy
# Time for file path generation: 26.6710 seconds
# Time for processing event: 26.6710 seconds
#
# Downloading VLASS1.2.ql.T15t15.J110143+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T15t15.J110143+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adalarn_VLASS1.2v2_array.npy
# Time for file path generation: 28.6470 seconds
# Time for processing event: 28.6481 seconds
#
# Downloading VLASS2.2.ql.T15t15.J110143+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T15t15.J110143+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adalarn_VLASS2.2_array.npy
# Time for file path generation: 15.5864 seconds
# Time for processing event: 15.5864 seconds
#
# Downloading VLASS3.2.ql.T15t15.J110143+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T15t15.J110143+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adalarn_VLASS3.2_array.npy
# Time for file path generation: 16.3457 seconds
# Time for processing event: 16.3457 seconds
#
# Downloading VLASS1.1.ql.T16t20.J145616+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T16t20.J145616+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adalgmc_VLASS1.1v2_array.npy
# Time for file path generation: 13.7524 seconds
# Time for processing event: 13.7524 seconds
#
# Downloading VLASS2.1.ql.T16t20.J145616+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T16t20.J145616+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adalgmc_VLASS2.1_array.npy
# Time for file path generation: 17.3178 seconds
# Time for processing event: 17.3178 seconds
#
# Downloading VLASS3.1.ql.T16t20.J145616+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T16t20.J145616+233000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adalgmc_VLASS3.1_array.npy
# Time for file path generation: 19.3316 seconds
# Time for processing event: 19.3328 seconds
#
# Downloading VLASS1.1.ql.T13t07.J042624+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T13t07.J042624+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaruzw_VLASS1.1v2_array.npy
# Time for file path generation: 13.5875 seconds
# Time for processing event: 13.5885 seconds
#
# Downloading VLASS2.1.ql.T13t07.J042624+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T13t07.J042624+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaruzw_VLASS2.1_array.npy
# Time for file path generation: 12.3644 seconds
# Time for processing event: 12.3644 seconds
#
# Downloading VLASS3.1.ql.T13t07.J042624+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T13t07.J042624+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaruzw_VLASS3.1_array.npy
# Time for file path generation: 14.0303 seconds
# Time for processing event: 14.0303 seconds
#
# Downloading VLASS1.2.ql.T17t10.J070501+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T17t10.J070501+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaslwa_VLASS1.2v2_array.npy
# Time for file path generation: 13.3574 seconds
# Time for processing event: 13.3574 seconds
#
# Downloading VLASS2.2.ql.T17t10.J070501+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T17t10.J070501+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaslwa_VLASS2.2_array.npy
# Time for file path generation: 12.0465 seconds
# Time for processing event: 12.0475 seconds
#
# Downloading VLASS3.2.ql.T17t10.J070501+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T17t10.J070501+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaslwa_VLASS3.2_array.npy
# Time for file path generation: 12.4576 seconds
# Time for processing event: 12.4576 seconds
#
# Downloading VLASS1.2.ql.T15t08.J052948+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T15t08.J052948+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adasopt_VLASS1.2v2_array.npy
# Time for file path generation: 12.6917 seconds
# Time for processing event: 12.6917 seconds
#
# Downloading VLASS2.2.ql.T15t08.J052948+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T15t08.J052948+193000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adasopt_VLASS2.2_array.npy
# Time for file path generation: 12.9816 seconds
# Time for processing event: 12.9827 seconds
#
# Downloading VLASS3.2.ql.T15t08.J052948+193000.10.2048.v3.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T15t08.J052948+193000.10.2048.v3.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adasopt_VLASS3.2_array.npy
# Time for file path generation: 13.4968 seconds
# Time for processing event: 13.4968 seconds
#
# Downloading VLASS1.2.ql.T20t04.J024709+393000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T20t04.J024709+393000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adathpb_VLASS1.2v2_array.npy
# Time for file path generation: 12.5307 seconds
# Time for processing event: 12.5307 seconds
#
# Downloading VLASS2.2.ql.T20t04.J024709+393000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T20t04.J024709+393000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adathpb_VLASS2.2_array.npy
# Time for file path generation: 13.3528 seconds
# Time for processing event: 13.3528 seconds
#
# Downloading VLASS3.2.ql.T20t04.J024709+393000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T20t04.J024709+393000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adathpb_VLASS3.2_array.npy
# Time for file path generation: 12.6313 seconds
# Time for processing event: 12.6313 seconds
#
# Downloading VLASS1.1.ql.T12t09.J055804+053000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T12t09.J055804+053000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adatosi_VLASS1.1v2_array.npy
# Time for file path generation: 13.7830 seconds
# Time for processing event: 13.7830 seconds
#
# Downloading VLASS2.1.ql.T12t09.J055804+053000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T12t09.J055804+053000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adatosi_VLASS2.1_array.npy
# Time for file path generation: 12.9343 seconds
# Time for processing event: 12.9343 seconds
#
# Downloading VLASS3.1.ql.T12t09.J055804+053000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T12t09.J055804+053000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adatosi_VLASS3.1_array.npy
# Time for file path generation: 13.4118 seconds
# Time for processing event: 13.4118 seconds
#
# Downloading VLASS1.2.ql.T17t12.J083034+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T17t12.J083034+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaylyq_VLASS1.2v2_array.npy
# Time for file path generation: 12.5758 seconds
# Time for processing event: 12.5758 seconds
#
# Downloading VLASS2.2.ql.T17t12.J083034+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T17t12.J083034+263000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaylyq_VLASS2.2_array.npy
# Time for file path generation: 14.3081 seconds
# Time for processing event: 14.3081 seconds
#
# Downloading VLASS3.2.ql.T17t12.J083034+263000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T17t12.J083034+263000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adaylyq_VLASS3.2_array.npy
# Time for file path generation: 62.7367 seconds
# Time for processing event: 62.7367 seconds
#
# Downloading VLASS1.1.ql.T13t14.J090224+113000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T13t14.J090224+113000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adazbol_VLASS1.1v2_array.npy
# Time for file path generation: 19.5173 seconds
# Time for processing event: 19.5173 seconds
#
# Downloading VLASS2.1.ql.T13t14.J090224+113000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T13t14.J090224+113000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adazbol_VLASS2.1_array.npy
# Time for file path generation: 21.3072 seconds
# Time for processing event: 21.3072 seconds
#
# Downloading VLASS3.1.ql.T13t14.J090224+113000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T13t14.J090224+113000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adazbol_VLASS3.1_array.npy
# Time for file path generation: 23.2162 seconds
# Time for processing event: 23.2162 seconds
#
# Downloading VLASS1.1.ql.T14t15.J094655+153000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T14t15.J094655+153000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adazgdh_VLASS1.1v2_array.npy
# Time for file path generation: 18.4975 seconds
# Time for processing event: 18.4975 seconds
#
# Downloading VLASS2.1.ql.T14t15.J094655+153000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T14t15.J094655+153000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adazgdh_VLASS2.1_array.npy
# Time for file path generation: 21.7198 seconds
# Time for processing event: 21.7198 seconds
#
# Downloading VLASS3.1.ql.T14t15.J094655+153000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T14t15.J094655+153000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adazgdh_VLASS3.1_array.npy
# Time for file path generation: 18.4217 seconds
# Time for processing event: 18.4217 seconds
#
# Downloading VLASS1.2.ql.T15t19.J141331+183000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T15t19.J141331+183000.10.2048.v2.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbadqp_VLASS1.2v2_array.npy
# Time for file path generation: 20.6882 seconds
# Time for processing event: 20.6882 seconds
#
# Downloading VLASS2.2.ql.T15t19.J141331+183000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T15t19.J141331+183000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbadqp_VLASS2.2_array.npy
# Time for file path generation: 41.8624 seconds
# Time for processing event: 41.8624 seconds
#
# Downloading VLASS3.2.ql.T15t19.J141331+183000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T15t19.J141331+183000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbadqp_VLASS3.2_array.npy
# Time for file path generation: 55.3900 seconds
# Time for processing event: 55.3900 seconds
#
# Downloading VLASS1.2.ql.T15t10.J070343+163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T15t10.J070343+163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbbhww_VLASS1.2v2_array.npy
# Time for file path generation: 35.5840 seconds
# Time for processing event: 35.5840 seconds
#
# Downloading VLASS2.2.ql.T15t10.J070343+163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T15t10.J070343+163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbbhww_VLASS2.2_array.npy
# Time for file path generation: 47.5459 seconds
# Time for processing event: 47.5459 seconds
#
# Downloading VLASS3.2.ql.T15t10.J070343+163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T15t10.J070343+163000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbbhww_VLASS3.2_array.npy
# Time for file path generation: 35.9676 seconds
# Time for processing event: 35.9676 seconds
#
# Downloading VLASS1.1.ql.T10t06.J033400-003000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T10t06.J033400-003000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbckox_VLASS1.1v2_array.npy
# Time for file path generation: 65.1778 seconds
# Time for processing event: 65.1778 seconds
#
# Downloading VLASS2.1.ql.T10t06.J033400-003000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T10t06.J033400-003000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbckox_VLASS2.1_array.npy
# Time for file path generation: 42.4349 seconds
# Time for processing event: 42.4349 seconds
#
# Downloading VLASS3.1.ql.T10t06.J033400-003000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T10t06.J033400-003000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbckox_VLASS3.1_array.npy
# Time for file path generation: 57.9283 seconds
# Time for processing event: 57.9283 seconds
#
# Downloading VLASS1.1.ql.T11t06.J033400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T11t06.J033400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbntwo_VLASS1.1v2_array.npy
# Time for file path generation: 48.0063 seconds
# Time for processing event: 48.0063 seconds
#
# Downloading VLASS2.1.ql.T11t06.J033400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T11t06.J033400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbntwo_VLASS2.1_array.npy
# Time for file path generation: 47.7383 seconds
# Time for processing event: 47.7383 seconds
#
# Downloading VLASS3.1.ql.T11t06.J033400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T11t06.J033400+013000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbntwo_VLASS3.1_array.npy
# Time for file path generation: 44.7333 seconds
# Time for processing event: 44.7333 seconds
#
# Downloading VLASS1.1.ql.T13t18.J115027+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T13t18.J115027+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbyxua_VLASS1.1v2_array.npy
# Time for file path generation: 26.6929 seconds
# Time for processing event: 26.6929 seconds
#
# Downloading VLASS2.1.ql.T13t18.J115027+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T13t18.J115027+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbyxua_VLASS2.1_array.npy
# Time for file path generation: 22.5849 seconds
# Time for processing event: 22.5849 seconds
#
# Downloading VLASS3.1.ql.T13t18.J115027+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T13t18.J115027+103000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adbyxua_VLASS3.1_array.npy
# Time for file path generation: 52.3102 seconds
# Time for processing event: 52.3102 seconds
#
# Downloading VLASS1.1.ql.T14t11.J065833+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T14t11.J065833+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adcdcrd_VLASS1.1v2_array.npy
# Time for file path generation: 39.2373 seconds
# Time for processing event: 39.2373 seconds
#
# Downloading VLASS2.1.ql.T14t11.J065833+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T14t11.J065833+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adcdcrd_VLASS2.1_array.npy
# Time for file path generation: 30.4060 seconds
# Time for processing event: 30.4060 seconds
#
# Downloading VLASS3.1.ql.T14t11.J065833+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T14t11.J065833+143000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF18adcdcrd_VLASS3.1_array.npy
# Time for file path generation: 29.8946 seconds
# Time for processing event: 29.8946 seconds
#
# ia_fits\VLASS1.1.ql.T17t18.J130042+273000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits already exists. Skipping download.
# Array saved to ia_npy_arrays\ZTF19aaafica_VLASS1.1v2_array.npy
# Time for file path generation: 3.3989 seconds
# Time for processing event: 3.3989 seconds
#
# ia_fits\VLASS2.1.ql.T17t18.J130042+273000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits already exists. Skipping download.
# Array saved to ia_npy_arrays\ZTF19aaafica_VLASS2.1_array.npy
# Time for file path generation: 2.8838 seconds
# Time for processing event: 2.8838 seconds
#
# ia_fits\VLASS3.1.ql.T17t18.J130042+273000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits already exists. Skipping download.
# Array saved to ia_npy_arrays\ZTF19aaafica_VLASS3.1_array.npy
# Time for file path generation: 3.5891 seconds
# Time for processing event: 3.5891 seconds
#
# Downloading VLASS1.1.ql.T12t36.J232200+073000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T12t36.J232200+073000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaagfme_VLASS1.1v2_array.npy
# Time for file path generation: 34.9058 seconds
# Time for processing event: 34.9058 seconds
#
# Downloading VLASS2.1.ql.T12t36.J232200+073000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T12t36.J232200+073000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaagfme_VLASS2.1_array.npy
# Time for file path generation: 43.9418 seconds
# Time for processing event: 43.9418 seconds
#
# Downloading VLASS3.1.ql.T12t36.J232200+073000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T12t36.J232200+073000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaagfme_VLASS3.1_array.npy
# Time for file path generation: 30.7642 seconds
# Time for processing event: 30.7642 seconds
#
# Downloading VLASS1.2.ql.T18t09.J062034+293000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T18t09.J062034+293000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaairqh_VLASS1.2v2_array.npy
# Time for file path generation: 38.6954 seconds
# Time for processing event: 38.6954 seconds
#
# Downloading VLASS2.2.ql.T18t09.J062034+293000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T18t09.J062034+293000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaairqh_VLASS2.2_array.npy
# Time for file path generation: 22.9145 seconds
# Time for processing event: 22.9145 seconds
#
# Downloading VLASS3.2.ql.T18t09.J062034+293000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T18t09.J062034+293000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaairqh_VLASS3.2_array.npy
# Time for file path generation: 21.7822 seconds
# Time for processing event: 21.7822 seconds
#
# Downloading VLASS1.2.ql.T08t13.J080603-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T08t13.J080603-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaaojck_VLASS1.2v2_array.npy
# Time for file path generation: 28.7074 seconds
# Time for processing event: 28.7074 seconds
#
# Downloading VLASS2.2.ql.T08t13.J080603-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T08t13.J080603-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaaojck_VLASS2.2_array.npy
# Time for file path generation: 34.3872 seconds
# Time for processing event: 34.3872 seconds
#
# Downloading VLASS3.2.ql.T08t13.J080603-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T08t13.J080603-083000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaaojck_VLASS3.2_array.npy
# Time for file path generation: 28.4132 seconds
# Time for processing event: 28.4132 seconds
#
# Downloading VLASS1.1.ql.T14t32.J211047+133000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.1.ql.T14t32.J211047+133000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaarhtg_VLASS1.1v2_array.npy
# Time for file path generation: 35.6280 seconds
# Time for processing event: 35.6280 seconds
#
# Downloading VLASS2.1.ql.T14t32.J211047+133000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.1.ql.T14t32.J211047+133000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaarhtg_VLASS2.1_array.npy
# Time for file path generation: 25.5700 seconds
# Time for processing event: 25.5748 seconds
#
# Downloading VLASS3.1.ql.T14t32.J211047+133000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.1.ql.T14t32.J211047+133000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aaarhtg_VLASS3.1_array.npy
# Time for file path generation: 32.0663 seconds
# Time for processing event: 32.0663 seconds
#
# Downloading VLASS1.2.ql.T22t09.J085919+473000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T22t09.J085919+473000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aabmybj_VLASS1.2v2_array.npy
# Time for file path generation: 30.6742 seconds
# Time for processing event: 30.6742 seconds
#
# Downloading VLASS2.2.ql.T22t09.J085919+473000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T22t09.J085919+473000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aabmybj_VLASS2.2_array.npy
# Time for file path generation: 22.1576 seconds
# Time for processing event: 22.1576 seconds
#
# Downloading VLASS3.2.ql.T22t09.J085919+473000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T22t09.J085919+473000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aabmybj_VLASS3.2_array.npy
# Time for file path generation: 23.4857 seconds
# Time for processing event: 23.4857 seconds
#
# Downloading VLASS1.2.ql.T09t13.J083802-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS1.2.ql.T09t13.J083802-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aabvfwn_VLASS1.2v2_array.npy
# Time for file path generation: 24.5175 seconds
# Time for processing event: 24.5175 seconds
#
# Downloading VLASS2.2.ql.T09t13.J083802-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS2.2.ql.T09t13.J083802-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aabvfwn_VLASS2.2_array.npy
# Time for file path generation: 24.8722 seconds
# Time for processing event: 24.8722 seconds
#
# Downloading VLASS3.2.ql.T09t13.J083802-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits...
# Downloaded VLASS3.2.ql.T09t13.J083802-043000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits successfully.
# Array saved to ia_npy_arrays\ZTF19aabvfwn_VLASS3.2_array.npy
# Time for file path generation: 33.0201 seconds
# Time for processing event: 33.0201 seconds
#
# Dataframe written to: ia_supernovae_with_file_path.csv
# Total time for all events: 3656.7245 seconds
# CSV updated: ia_supernovae_with_file_path.csv

# %% [markdown]
# [{'Name': 'ZTF17aabtvsy',
#   'c': <SkyCoord (ICRS): (ra, dec) in deg
#       (158.88370833, 37.64972222)>,
#   'Tile': 'T20t14',
#   'Epoch': 'VLASS1.2',
#   'Date': '2019-05-03'},

# %%
np.load("ia_npy_arrays/ZTF19aailqli_VLASS3.1_array.npy")
# Out:
# array([[-2.86993854e-05,  3.93245682e-05, -4.70624072e-05,
#          5.50049590e-05,  1.08721979e-04,  7.75309672e-05,
#          8.24702947e-05,  3.48857066e-05,  9.46950458e-05,
#          1.00778998e-04,  1.34430535e-04,  1.17279611e-04],
#        [ 1.44338119e-04,  8.97992140e-05, -3.02855697e-05,
#          3.54980002e-05,  1.00247207e-05, -1.03055390e-04,
#         -5.60985136e-05, -3.02234616e-06, -3.28140013e-05,
#          8.28056727e-06,  1.26051309e-04,  1.26114159e-04],
#        [ 1.53838671e-04, -4.10844514e-05, -5.03865795e-06,
#          5.73185171e-05, -2.89495492e-05, -9.41745457e-05,
#         -1.04503451e-04, -3.22662163e-05, -3.27167327e-05,
#         -8.78374267e-05, -1.10497995e-05,  3.07345290e-05],
#        [ 1.04825311e-04, -1.12922957e-04, -1.29248816e-04,
#         -3.10015530e-05,  2.98146060e-05,  7.42764096e-05,
#          9.63672064e-05,  1.16571966e-04,  9.23050393e-05,
#         -1.64828216e-05, -9.94584407e-05, -3.60789236e-05],
#        [-2.92496879e-05, -1.45010956e-04, -8.75863552e-05,
#         -5.73250363e-05,  7.18289157e-05,  8.65373513e-05,
#          4.49978006e-06, -2.60216325e-06,  1.03773571e-04,
#          1.75252528e-04,  6.33786622e-05,  2.67678097e-05],
#        [ 7.23615522e-05, -2.49495788e-05, -8.03914227e-05,
#         -1.73619701e-04, -9.08651327e-06,  4.29455904e-05,
#         -9.50021858e-05, -1.27319625e-04,  1.03142011e-04,
#          2.16215049e-04,  7.04372142e-05,  8.38379856e-05],
#        [-1.49686648e-05, -2.21826253e-04, -2.56280415e-04,
#         -1.06177475e-04,  1.72029962e-04,  8.57262712e-05,
#         -1.02097780e-04, -1.72122032e-04, -9.05422621e-06,
#          1.10829766e-04, -6.52240342e-05, -1.96689598e-05],
#        [-1.18311960e-04, -1.24345665e-04, -1.86191086e-04,
#          1.12612852e-05,  2.34808263e-04,  7.15043188e-06,
#         -9.82777055e-05, -3.43268330e-05, -3.92245638e-05,
#         -3.07819391e-05, -3.17873637e-05, -3.67854300e-05],
#        [-6.99582743e-05,  5.00315036e-05, -1.31304669e-05,
#         -1.07677106e-05,  1.20448967e-04,  3.91878784e-05,
#          4.50767438e-05,  8.71480661e-05,  9.54180286e-05,
#          1.13134331e-04,  5.10431164e-05,  3.67882130e-05],
#        [-1.21942758e-05, -1.91728714e-06,  1.21516612e-04,
#          1.70900403e-05, -3.17839986e-05, -5.76430512e-06,
#          6.17729966e-05,  1.43690049e-04,  1.42084260e-04,
#          4.58121613e-05,  9.79457473e-05,  2.40050329e-04],
#        [ 3.33275093e-05,  3.07386199e-06,  1.60900920e-04,
#         -8.25326970e-06, -1.41624114e-04, -1.20126759e-04,
#          3.13148958e-05,  1.43352256e-04, -5.32715967e-06,
#         -1.28550455e-04,  9.88180036e-05,  2.96094513e-04],
#        [ 1.12995549e-04,  1.45671147e-05,  1.13548063e-04,
#         -7.68850441e-06, -1.33596055e-04, -4.76313144e-05,
#          6.67346976e-05,  1.33823283e-04,  3.54061849e-05,
#         -3.56823330e-05,  6.56101402e-05,  1.77114329e-04]], dtype=float32)

# %%
maxi_ra = "12h10m01.32s"
maxi_dec = "+49d56m47.006s"
maxi = SkyCoord(ra = maxi_ra, dec = maxi_dec)

# %%
def run_search(name, c, date=None):
    """ 
    Searches the VLASS catalog for a source

    Parameters
    ----------
    names: name of the sources
    c: coordinates as SkyCoord object
    date: date in astropy Time format
    """
    print("Running for %s" %name)
    print("Coordinates %s" %c)
    print("Date: %s" %date)

    # Find the VLASS tile(s)
    tiles = get_tiles()
    tilenames, epochs, obsdates = search_tiles(tiles, c)

    # Sort the tiles by the epochs so most recent goes last
    combined = list(zip(tilenames, epochs, obsdates))
    combined_sorted = sorted(combined, key=lambda x: x[1])
    tilenames, epochs, obsdates = zip(*combined_sorted)

    past_epochs = ["VLASS1.1v2", "VLASS1.2v2", "VLASS2.1", "VLASS2.2", "VLASS3.1"]
    current_epoch = "VLASS3.2"

    results = []
    list_epochs = []
    list_dates = []

    url_full = 'https://archive-new.nrao.edu/vlass/quicklook/%s/' %(current_epoch)
    with closing(urlopen(url_full)) as urlpath:
        # Get site HTML coding
        string = (urlpath.read().decode('utf-8')).split("\n")
        # clean the HTML elements of trailing and leading whitespace
        vals = np.array([val.strip() for val in string])
        # Make list of useful html elements
        files = np.array(['alt="[DIR]"' in val.strip() for val in string])
        useful = vals[files]
        # Splice out the name from the link
        obsname = np.array([val.split("\"")[7] for val in useful])
        observed_current_epoch = np.char.replace(obsname, '/', '')

    if tilenames[0] is None:
        print("There is no VLASS tile at this location")
        results = ['images\\unimaged.png', 'images\\unimaged.png', 'images\\unimaged.png']
        list_epochs = ['NA', 'NA', 'NA']
        list_dates = ['NA', 'NA', 'NA']
        return results, list_epochs, list_dates

    else:
        for ii,tilename in enumerate(tilenames):
            start_time = time.time()
            print()
            print("Looking for tile observation for %s" %tilename)
            epoch = epochs[ii]
            obsdate = obsdates[ii]
            if obsdate not in ['Scheduled', 'Not submitted']:
                try:
                    obsdate = Time(obsdate, format='iso')
                except ValueError as e:
                    print(f"Invalid date format: {obsdate}. Error: {e}")
                    obsdate = 'Invalid date'
            else:
                obsdate = 'Invalid date'
            # Adjust name so it works with the version 2 ones for 1.1 and 1.2
            if epoch=='VLASS1.2':
                epoch = 'VLASS1.2v2'
            elif epoch =='VLASS1.1':
                epoch = 'VLASS1.1v2'

            observed = True

            if epoch not in past_epochs:
                if epoch == current_epoch:
                    # Check if tile has been observed yet for the current epoch
                    if epoch not in observed_current_epoch:
                        observed = False
                        results.append('images\\unimaged.png')
                        list_epochs.append(epoch)
                        list_dates.append(obsdate)
                        print("Sorry, tile will be observed later in this epoch")
                else:
                    observed = False
                    results.append('images\\unimaged.png')
                    list_epochs.append(epoch)
                    list_dates.append(obsdate)
                    print("Sorry, tile will be observed in a later epoch")
                    
            if observed:
                subtiles, c_tiles = get_subtiles(tilename, epoch)
                if c_tiles == []:
                    observed = False
                    results.append('images\\unimaged.png')
                    list_epochs.append(epoch)
                    list_dates.append(obsdate)
                    print("Sorry, tile is not imaged at the position of the source")
                else:
                    print("Tile Found:")
                    print(tilename, epoch)
                    # Find angular separation from the tiles to the location
                    dist = c.separation(c_tiles)
                    # Find tile with the smallest separation 
                    subtile = subtiles[np.argmin(dist)]
                    url_get = "https://archive-new.nrao.edu/vlass/quicklook/%s/%s/%s" %(
                            epoch, tilename, subtile)
                    imname="%s.I.iter1.image.pbcor.tt0.subim.fits" %subtile[0:-1]
                    fname = url_get + imname
                    print(fname)
                    png_name = "images\\" + name + "_" + epoch + ".png"
                    if os.path.exists(png_name):
                        print(f"PNG file {png_name} already exists. Skipping download.")
                    else:
                        # Ensure the new_fits directory exists
                        fits_dir = "new_fits"
                        if not os.path.exists(fits_dir):
                            os.makedirs(fits_dir)

                        # Define the local path for the downloaded FITS file
                        local_fits_path = os.path.join(fits_dir, imname)
    
                        # Download the FITS file to the new_fits directory
                        cmd = f"curl -o {local_fits_path} {fname}"
                        print(cmd)
                        os.system(cmd)
    
                        # Call get_cutout with the local path of the FITS file
                        out = get_cutout(local_fits_path, name, c, epoch)
                        out = None

                        if out is not None:
                            peak, rms, png_name = out
                            print("Peak flux is %s uJy" %(peak*1e6))
                            print("RMS is %s uJy" %(rms*1e6))
                            limit = rms*1e6
                            print("Tile observed on %s" %obsdate)
                            print(limit, obsdate)
                        else:
                            png_name = "images\\unimaged.png"
                            print("Sorry, tile has not been imaged at the position of the source")
                    # append list elements
                    results.append(png_name)
                    list_epochs.append(epoch)
                    list_dates.append(obsdate)  

                end_time = time.time()
                duration = end_time - start_time
                print(f"Run search completed in {duration:.2f} seconds.")

        return results, list_epochs, list_dates

# %%
maxi_ra = "12h10m01.32s"
maxi_dec = "+49d56m47.006s"
maxi = SkyCoord(ra = maxi_ra, dec = maxi_dec)

run_search("MAXI", maxi)

ra_fungi = "16h43m48.201s"
dec_fungi = "+41d02m43.38s"
first_guy = SkyCoord(ra = ra_fungi, dec = dec_fungi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24328\267207749.py in <module>
#       3 maxi = SkyCoord(ra = maxi_ra, dec = maxi_dec)
#       4
# ----> 5 run_search("MAXI", maxi)
#       6
#       7 ra_fungi = "16h43m48.201s"
#
# NameError: name 'run_search' is not defined

# %%
run_search("SN2018gep", first_guy)
# Out:
# Running for SN2018gep
# Coordinates <SkyCoord (ICRS): (ra, dec) in deg
#     (250.9508375, 41.04538333)>
# Date: None
#
# Looking for tile observation for T21t17
# Tile Found:
# T21t17 VLASS1.2v2
# https://archive-new.nrao.edu/vlass/quicklook/VLASS1.2v2/T21t17/
# https://archive-new.nrao.edu/vlass/quicklook/VLASS1.2v2/T21t17/VLASS1.2.ql.T21t17.J164503+413000.10.2048.v1/VLASS1.2.ql.T21t17.J164503+413000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits
# Generating cutout
# Cutout centered at position 250.95083749999995, 41.045383333333334
# PNG Downloaded Successfully
# Peak flux is 297.11684328503907 uJy
# RMS is 134.05616850692218 uJy
# Tile observed on 58607.0
# 134.05616850692218 58607.0
#
# Looking for tile observation for T21t17
# Tile Found:
# T21t17 VLASS2.2
# https://archive-new.nrao.edu/vlass/quicklook/VLASS2.2/T21t17/
# https://archive-new.nrao.edu/vlass/quicklook/VLASS2.2/T21t17/VLASS2.2.ql.T21t17.J164503+413000.10.2048.v1/VLASS2.2.ql.T21t17.J164503+413000.10.2048.v1.I.iter1.image.pbcor.tt0.subim.fits
# Generating cutout
# Cutout centered at position 250.95083749999995, 41.045383333333334
# PNG Downloaded Successfully
# Peak flux is 241.5875787846744 uJy
# RMS is 112.8708448274466 uJy
# Tile observed on 59532.0
# 112.8708448274466 59532.0
#
# Looking for tile observation for T21t17
# Sorry, tile will be observed later in this epoch

# %%
if __name__=="__main__":
    parser = argparse.ArgumentParser(description=\
        '''
        Searches VLASS for a source.
        User needs to supply name, RA (in decimal degrees),
        Dec (in decimal degrees), and (optionally) date (in mjd).
        If there is a date, then will only return VLASS images taken after that date
        (useful for transients with known explosion dates).
        
        Usage: vlass_search.py <Name> <RA [deg]> <Dec [deg]> <(optional) Date [mjd]>
        ''', formatter_class=argparse.RawTextHelpFormatter)
        
    #Check if correct number of arguments are given
    if len(sys.argv) < 3:
        print("Usage: vlass_search.py <Name> <RA [deg]> <Dec [deg]> <(optional) Date [astropy Time]>")
        sys.exit()
     
    name = str(sys.argv[1])
    ra = float(sys.argv[2])
    dec = float(sys.argv[3])
    c = SkyCoord(ra, dec, unit='deg')

    if glob.glob("/Users/annaho/Dropbox/astro/tools/Query_VLASS/VLASS_dyn_summary.php"):
        pass
    else:
        print("Tile summary file is not here. Download it using wget:\
               wget https://archive-new.nrao.edu/vlass/VLASS_dyn_summary.php")

    if (len(sys.argv) > 4):
        date = Time(float(sys.argv[4]), format='mjd')
        print ('Searching for observations after %s' %date)
        run_search(name, c, date) 
    else:
        print ('Searching all obs dates')
        run_search(name, c)
# Out:
# Usage: vlass_search.py <Name> <RA [deg]> <Dec [deg]> <(optional) Date [astropy Time]>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
